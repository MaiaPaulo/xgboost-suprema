# %%
# LIBRARIES
import snowflake.connector
import logging
from os import environ
from dotenv import load_dotenv
import pandas as pd
import xgboost as xgb
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, KFold
import optuna
import joblib
import numpy as np

# %%
# SNOWFLAKE CONNECTION 
load_dotenv()
for logger_name in ['snowflake.connector', 'botocore']:
    logger = logging.getLogger(logger_name)
    logger.setLevel(logging.DEBUG)
    handler = logging.StreamHandler()
    handler.setLevel(logging.DEBUG)
    logger.addHandler(handler)

conn = snowflake.connector.connect(
    user = environ['USER'],
    password = environ['PASSWORD'],
    account = environ['ACCOUNT'],
    warehouse = environ['WAREHOUSE'],
    database = environ['DATABASE'],
    schema = environ['SCHEMA']
)
# Out:
# Snowflake Connector for Python Version: 3.12.2, Python Version: 3.10.14, Platform: Windows-10-10.0.22631-SP0
# connect
# __config
# Connecting to GLOBAL Snowflake domain
# This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# use_numpy: False
# initialized
# REST API object was created: fa62087.us-east-2.aws.snowflakecomputing.com:443
# authenticate
# assertion content: *********
# account=fa62087, user=PAULO_MAIA, database=POKER_PROD, schema=POKER, warehouse=REPORTING_POKER_WH, role=None, request_id=02d264df-48f3-4b84-8e20-77e0f07136ab
# body['data']: {'CLIENT_APP_ID': 'PythonConnector', 'CLIENT_APP_VERSION': '3.12.2', 'SVN_REVISION': None, 'ACCOUNT_NAME': 'fa62087', 'LOGIN_NAME': 'PAULO_MAIA', 'CLIENT_ENVIRONMENT': {'APPLICATION': 'PythonConnector', 'OS': 'Windows', 'OS_VERSION': 'Windows-10-10.0.22631-SP0', 'PYTHON_VERSION': '3.10.14', 'PYTHON_RUNTIME': 'CPython', 'PYTHON_COMPILER': 'MSC v.1916 64 bit (AMD64)', 'OCSP_MODE': 'FAIL_OPEN', 'TRACING': 10, 'LOGIN_TIMEOUT': None, 'NETWORK_TIMEOUT': None, 'SOCKET_TIMEOUT': None}, 'SESSION_PARAMETERS': {'CLIENT_PREFETCH_THREADS': 4}}
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# Session status for SessionPool 'fa62087.us-east-2.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# remaining request timeout: N/A ms, retry cnt: 1
# Request guid: d5490d9f-c4ff-4298-9ec6-7edabe30aa1b
# socket timeout: 60
# Starting new HTTPS connection (1): fa62087.us-east-2.aws.snowflakecomputing.com:443
# OCSP Mode: FAIL_OPEN, OCSP response cache file name: None
# cache directory: C:\Users\maiap\AppData\Local\Snowflake\Caches
# ocsp_response_cache_uri: file://C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# OCSP_VALIDATION_CACHE size: 0
# OCSP response cache server is enabled: http://ocsp.snowflakecomputing.com/ocsp_response_cache.json
# OCSP dynamic cache server RETRY URL: None
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-01-15 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-05-07 12:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Failed to validate ocsp response 254013: 254013: Response is unreliable. Its validity date is out of range: current_time=2024-11-29 14:35:29Z, this_update=2024-11-21 17:45:02Z, next_update=2024-11-28 16:45:02Z, tolerable next_update=2024-11-28 18:25:14Z. A potential cause is client clock is skewed, CA fails to update OCSP response in time.
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:17+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Failed to validate ocsp response 254013: 254013: Response is unreliable. Its validity date is out of range: current_time=2024-11-29 14:35:29Z, this_update=2024-11-22 05:33:02Z, next_update=2024-11-29 04:33:02Z, tolerable next_update=2024-11-29 06:13:14Z. A potential cause is client clock is skewed, CA fails to update OCSP response in time.
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:17+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:17+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:17+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:19+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-25 15:50:17+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2024-12-23 15:50:16+00:00
# Read OCSP response cache file: C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json, count=295
# validating certificate: fa62087.us-east-2.aws.snowflakecomputing.com
# # of certificates: 4
# subject: OrderedDict([('common_name', '*.us-east-2.snowflakecomputing.com')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M02')])
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M02')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')]), issuer: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# reading certificate bundle: C:\Users\maiap\anaconda3\envs\suprema-env\lib\site-packages\certifi\cacert.pem
# not found issuer_der: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# hit cache for subject: OrderedDict([('common_name', '*.us-east-2.snowflakecomputing.com')])
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M02')])
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-05-07 12:00:00+00:00
# hit cache for subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# hit cache for subject: OrderedDict([('common_name', '*.us-east-2.snowflakecomputing.com')])
# using OCSP response cache
# Certificate is NOT attached in Basic OCSP Response. Using issuer's certificate
# Verifying the OCSP response is signed by the issuer.
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M02')])
# using OCSP response cache
# Certificate is attached in Basic OCSP Response
# Verifying the attached certificate is signed by the issuer
# Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the OCSP response is signed by the issuer.
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# using OCSP response cache
# Certificate is attached in Basic OCSP Response
# Verifying the attached certificate is signed by the issuer
# Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the OCSP response is signed by the issuer.
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-05-07 12:00:00+00:00
# hit cache for subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# using OCSP response cache
# Certificate is attached in Basic OCSP Response
# Verifying the attached certificate is signed by the issuer
# Valid Not After: 2025-05-07 12:00:00+00:00
# Verifying the OCSP response is signed by the issuer.
# writing OCSP response cache file to C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# encoding OCSP response cache to JSON
# ok
# https://fa62087.us-east-2.aws.snowflakecomputing.com:443 "POST /session/v1/login-request?request_id=02d264df-48f3-4b84-8e20-77e0f07136ab&databaseName=POKER_PROD&schemaName=POKER&warehouse=REPORTING_POKER_WH&request_guid=d5490d9f-c4ff-4298-9ec6-7edabe30aa1b HTTP/1.1" 200 4724
# SUCCESS
# Session status for SessionPool 'fa62087.us-east-2.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# ret[code] = None, after post request
# completed authentication
# token = ******
# master_token = ******
# id_token = NULL
# mfa_token = NULL

# %%
# SELECTING THE QUERY AND GETTING THE DATA
with open('training_query.sql', 'r') as file:
    query = file.read()
    
data = pd.read_sql_query(query, conn)
# Out:
# C:\Users\maiap\AppData\Local\Temp\ipykernel_30568\672369880.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(query, conn)
# cursor
# executing SQL/command
# query: [WITH counts AS ( SELECT start_date_local, start_hour_local, COUNT(*) AS same_hou...]
# binding: [WITH counts AS ( SELECT start_date_local, start_hour_local, COUNT(*) AS same_hou...] with input=[None], processed=[{}]
# sequence counter: 1
# Request id: 5f22852d-8eff-44bf-a9b0-b52af04be848
# running query [WITH counts AS ( SELECT start_date_local, start_hour_local, COUNT(*) AS same_hou...]
# is_file_transfer: True
# _cmd_query
# serialize_to_dict() called
# sql=[WITH counts AS ( SELECT start_date_local, start_hour_local, COUNT(*) AS same_hou...], sequence_id=[1], is_file_transfer=[False]
# Opentelemtry otel injection failed because of: No module named 'opentelemetry'
# Session status for SessionPool 'fa62087.us-east-2.aws.snowflakecomputing.com', SessionPool 1/1 active sessions
# remaining request timeout: N/A ms, retry cnt: 1
# Request guid: ac0e2cca-ce09-4c9c-90d8-bbbbabc1e5bd
# socket timeout: 60
# https://fa62087.us-east-2.aws.snowflakecomputing.com:443 "POST /queries/v1/query-request?requestId=5f22852d-8eff-44bf-a9b0-b52af04be848&request_guid=ac0e2cca-ce09-4c9c-90d8-bbbbabc1e5bd HTTP/1.1" 200 None
# SUCCESS
# Session status for SessionPool 'fa62087.us-east-2.aws.snowflakecomputing.com', SessionPool 0/1 active sessions
# ret[code] = None, after post request
# Query id: 01b8b27e-0002-3911-0004-f43601bdefaa
# deserialize_json_dict() called: data from server: {'entries': [{'id': 0, 'timestamp': 1732892079250531, 'priority': 0, 'context': 'CMbIIw=='}]}
# deserialize {'id': 0, 'timestamp': 1732892079250531, 'priority': 0, 'context': 'CMbIIw=='}
# sync_priority_map called priority_map size = 0, new_priority_map size = 1
# trim_cache() called. treeSet size is 1 and cache capacity is 5
# trim_cache() returns. treeSet size is 1 and cache capacity is 5
# deserialize_json_dict() returns
# Cache Entry: (0, 1732892079250531, 0)
# sfqid: 01b8b27e-0002-3911-0004-f43601bdefaa
# query execution done
# SUCCESS
# PUT OR GET: False
# Query result format: arrow
# chunk size=4
# Number of results in first chunk: 638
# Using nanoarrow as the arrow data converter
# Arrow BatchSize: 1
# Arrow chunk info: batchCount 1, columnCount 26, use_numpy: 0
# Batches read: 0
# result batch 1 has id: data_0_0_1_1
# result batch 2 has id: data_0_0_2_1
# result batch 3 has id: data_0_0_3_1
# result batch 4 has id: data_0_0_4_1
# beginning to schedule result batch downloads
# queuing download of result batch id: data_0_0_1_1
# started downloading result batch id: data_0_0_1_1
# queuing download of result batch id: data_0_0_2_1
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# started downloading result batch id: data_0_0_2_1
# queuing download of result batch id: data_0_0_3_1
# Session status for SessionPool 'None', SessionPool 1/1 active sessions
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# started downloading result batch id: data_0_0_3_1
# queuing download of result batch id: data_0_0_4_1
# downloading result batch id: data_0_0_1_1 with existing session <snowflake.connector.vendored.requests.sessions.Session object at 0x000001F4DC8B08B0>
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# started downloading result batch id: data_0_0_4_1
# Current batch index: 0, rows in current batch: 638
# Session status for SessionPool 'None', SessionPool 2/2 active sessions
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# user requesting to consume result batch 1
# downloading result batch id: data_0_0_2_1 with existing session <snowflake.connector.vendored.requests.sessions.Session object at 0x000001F4DC8B09A0>
# Session status for SessionPool 'None', SessionPool 3/3 active sessions
# Converted retries value: 1 -> Retry(total=1, connect=None, read=None, redirect=None, status=None)
# Starting new HTTPS connection (1): sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com:443
# downloading result batch id: data_0_0_3_1 with existing session <snowflake.connector.vendored.requests.sessions.Session object at 0x000001F4DC910220>
# Starting new HTTPS connection (1): sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com:443
# Session status for SessionPool 'None', SessionPool 4/4 active sessions
# Starting new HTTPS connection (1): sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com:443
# downloading result batch id: data_0_0_4_1 with existing session <snowflake.connector.vendored.requests.sessions.Session object at 0x000001F4DC910A30>
# Starting new HTTPS connection (1): sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com:443
# OCSP Mode: FAIL_OPEN, OCSP response cache file name: None
# OCSP Mode: FAIL_OPEN, OCSP response cache file name: None
# ocsp_response_cache_uri: file://C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# OCSP_VALIDATION_CACHE size: 295
# OCSP response cache server is enabled: http://ocsp.snowflakecomputing.com/ocsp_response_cache.json
# ocsp_response_cache_uri: file://C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# OCSP_VALIDATION_CACHE size: 295
# OCSP dynamic cache server RETRY URL: None
# OCSP response cache server is enabled: http://ocsp.snowflakecomputing.com/ocsp_response_cache.json
# validating certificate: sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com
# OCSP dynamic cache server RETRY URL: None
# validating certificate: sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com
# # of certificates: 4
# # of certificates: 4
# subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# OCSP Mode: FAIL_OPEN, OCSP response cache file name: None
# OCSP Mode: FAIL_OPEN, OCSP response cache file name: None
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# ocsp_response_cache_uri: file://C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# ocsp_response_cache_uri: file://C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')]), issuer: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')]), issuer: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# OCSP_VALIDATION_CACHE size: 295
# OCSP_VALIDATION_CACHE size: 295
# subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# OCSP response cache server is enabled: http://ocsp.snowflakecomputing.com/ocsp_response_cache.json
# OCSP dynamic cache server RETRY URL: None
# not found issuer_der: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# not found issuer_der: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# OCSP response cache server is enabled: http://ocsp.snowflakecomputing.com/ocsp_response_cache.json
# OCSP dynamic cache server RETRY URL: None
# hit cache for subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')])
# hit cache for subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')])
# validating certificate: sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com
# validating certificate: sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# # of certificates: 4
# # of certificates: 4
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')]), issuer: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')]), issuer: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-05-07 12:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-05-07 12:00:00+00:00
# subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')]), issuer: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# not found issuer_der: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# not found issuer_der: OrderedDict([('country_name', 'US'), ('organization_name', 'Starfield Technologies, Inc.'), ('organizational_unit_name', 'Starfield Class 2 Certification Authority')])
# hit cache for subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')])
# hit cache for subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')])
# hit cache for subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')])
# hit cache for subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')])
# using OCSP response cache
# using OCSP response cache
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Certificate is NOT attached in Basic OCSP Response. Using issuer's certificate
# Certificate is NOT attached in Basic OCSP Response. Using issuer's certificate
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# Verifying the OCSP response is signed by the issuer.
# Verifying the OCSP response is signed by the issuer.
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2026-07-22 00:00:00+00:00
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon Root CA 1')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('organization_name', 'Amazon'), ('common_name', 'Amazon RSA 2048 M01')])
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-05-07 12:00:00+00:00
# Verifying the attached certificate is signed by the issuer. Valid Not After: 2025-05-07 12:00:00+00:00
# using OCSP response cache
# using OCSP response cache
# hit cache for subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# hit cache for subject: OrderedDict([('country_name', 'US'), ('state_or_province_name', 'Arizona'), ('locality_name', 'Scottsdale'), ('organization_name', 'Starfield Technologies, Inc.'), ('common_name', 'Starfield Services Root Certificate Authority - G2')])
# Certificate is attached in Basic OCSP Response
# Certificate is attached in Basic OCSP Response
# Verifying the attached certificate is signed by the issuer
# hit cache for subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')])
# Verifying the attached certificate is signed by the issuer
# hit cache for subject: OrderedDict([('common_name', '*.s3.us-east-2.amazonaws.com')])
# Valid Not After: 2026-07-22 00:00:00+00:00
# using OCSP response cache
# Valid Not After: 2026-07-22 00:00:00+00:00
# using OCSP response cache
# Certificate is NOT attached in Basic OCSP Response. Using issuer's certificate
# Certificate is NOT attached in Basic OCSP Response. Using issuer's certificate
# Verifying the OCSP response is signed by the issuer.
# Verifying the OCSP response is signed by the issuer.
# Verifying the OCSP response is signed by the issuer.
# Verifying the OCSP response is signed by the issuer.
# writing OCSP response cache file to C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# encoding OCSP response cache to JSON
# ok
# writing OCSP response cache file to C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# encoding OCSP response cache to JSON
# ok
# writing OCSP response cache file to C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# encoding OCSP response cache to JSON
# ok
# writing OCSP response cache file to C:/Users/maiap/AppData/Local/Snowflake/Caches/ocsp_response_cache.json
# encoding OCSP response cache to JSON
# ok
# https://sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com:443 "GET /rwkg0000-s/results/01b8b27e-0002-3911-0004-f43601bdefaa_0/main/data_0_0_1_1?x-amz-server-side-encryption-customer-algorithm=AES256&response-content-encoding=gzip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241129T145439Z&X-Amz-SignedHeaders=host&X-Amz-Expires=21599&X-Amz-Credential=AKIAVTVUO2PHYMHEMPGG%2F20241129%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Signature=d79ba3c6b99623889c4983623a7b1a69c84791e1540032e4409da75005585db2 HTTP/1.1" 200 134974
# https://sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com:443 "GET /rwkg0000-s/results/01b8b27e-0002-3911-0004-f43601bdefaa_0/main/data_0_0_2_1?x-amz-server-side-encryption-customer-algorithm=AES256&response-content-encoding=gzip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241129T145439Z&X-Amz-SignedHeaders=host&X-Amz-Expires=21599&X-Amz-Credential=AKIAVTVUO2PHYMHEMPGG%2F20241129%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Signature=f687c6bbab4e0698516f10237f78873fc964457608b7a36dbc0f55af0ba93be3 HTTP/1.1" 200 214444
# https://sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com:443 "GET /rwkg0000-s/results/01b8b27e-0002-3911-0004-f43601bdefaa_0/main/data_0_0_4_1?x-amz-server-side-encryption-customer-algorithm=AES256&response-content-encoding=gzip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241129T145439Z&X-Amz-SignedHeaders=host&X-Amz-Expires=21599&X-Amz-Credential=AKIAVTVUO2PHYMHEMPGG%2F20241129%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Signature=b88dba609b33173de5d92c8c5d97a8e0bd39c407a2ad3a34cf4eb081c20e0948 HTTP/1.1" 200 633459
# https://sfc-oh-ds1-52-customer-stage.s3.us-east-2.amazonaws.com:443 "GET /rwkg0000-s/results/01b8b27e-0002-3911-0004-f43601bdefaa_0/main/data_0_0_3_1?x-amz-server-side-encryption-customer-algorithm=AES256&response-content-encoding=gzip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241129T145439Z&X-Amz-SignedHeaders=host&X-Amz-Expires=21599&X-Amz-Credential=AKIAVTVUO2PHYMHEMPGG%2F20241129%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Signature=6e74143972ca518448e829d95163e1184abcad8abff6b25946ec42c1a72d6ba4 HTTP/1.1" 200 515315
# Session status for SessionPool 'None', SessionPool 3/4 active sessions
# successfully downloaded result batch id: data_0_0_1_1
# started loading result batch id: data_0_0_1_1
# Using nanoarrow as the arrow data converter
# Arrow BatchSize: 5
# Arrow chunk info: batchCount 5, columnCount 26, use_numpy: 0
# Batches read: 0
# finished loading result batch id: data_0_0_1_1
# user began consuming result batch 1
# Current batch index: 0, rows in current batch: 653
# Current batch index: 1, rows in current batch: 646
# Current batch index: 2, rows in current batch: 644
# Current batch index: 3, rows in current batch: 641
# Current batch index: 4, rows in current batch: 639
# user finished consuming result batch 1
# user requesting to consume result batch 2
# Session status for SessionPool 'None', SessionPool 2/4 active sessions
# successfully downloaded result batch id: data_0_0_2_1
# started loading result batch id: data_0_0_2_1
# Using nanoarrow as the arrow data converter
# Arrow BatchSize: 7
# Arrow chunk info: batchCount 7, columnCount 26, use_numpy: 0
# Batches read: 0
# finished loading result batch id: data_0_0_2_1
# user began consuming result batch 2
# Current batch index: 0, rows in current batch: 634
# Current batch index: 1, rows in current batch: 631
# Current batch index: 2, rows in current batch: 653
# Current batch index: 3, rows in current batch: 652
# Current batch index: 4, rows in current batch: 644
# Current batch index: 5, rows in current batch: 642
# Current batch index: 6, rows in current batch: 1277
# user finished consuming result batch 2
# user requesting to consume result batch 3
# Session status for SessionPool 'None', SessionPool 1/4 active sessions
# successfully downloaded result batch id: data_0_0_4_1
# started loading result batch id: data_0_0_4_1
# Using nanoarrow as the arrow data converter
# Arrow BatchSize: 4
# Arrow chunk info: batchCount 4, columnCount 26, use_numpy: 0
# Batches read: 0
# finished loading result batch id: data_0_0_4_1
# Session status for SessionPool 'None', SessionPool 0/4 active sessions
# successfully downloaded result batch id: data_0_0_3_1
# started loading result batch id: data_0_0_3_1
# Using nanoarrow as the arrow data converter
# Arrow BatchSize: 6
# Arrow chunk info: batchCount 6, columnCount 26, use_numpy: 0
# Batches read: 0
# finished loading result batch id: data_0_0_3_1
# user began consuming result batch 3
# Current batch index: 0, rows in current batch: 1290
# Current batch index: 1, rows in current batch: 1292
# Current batch index: 2, rows in current batch: 2560
# Current batch index: 3, rows in current batch: 2587
# Current batch index: 4, rows in current batch: 2546
# Current batch index: 5, rows in current batch: 2595
# user finished consuming result batch 3
# user requesting to consume result batch 4
# user began consuming result batch 4
# Current batch index: 0, rows in current batch: 5142
# Current batch index: 1, rows in current batch: 5140
# Current batch index: 2, rows in current batch: 5127
# Current batch index: 3, rows in current batch: 573
# user finished consuming result batch 4

# %%
# Converter para o formato de data
data['START_DATE_LOCAL'] = pd.to_datetime(data['START_DATE_LOCAL'])
# Definir o tamanho das janelas
training_window = pd.DateOffset(months=11)
validation_window = pd.DateOffset(months=1)

# Criar o loop das janelas
start_date = pd.to_datetime('2023-07-30')  # Primeira janela de validação
end_date = (pd.Timestamp.now() - pd.DateOffset(days=1)).date()
end_date = pd.Timestamp(end_date)  # Converte para Timestamp# Última janela de validação
current_date = start_date

# %%
# ENCODING CATEGORICAL COLUMNS AND DEFINING X AND Y
encoder = OneHotEncoder(sparse_output=False)
data_transform = data.drop(columns=['MATCH_ID'])
cat_columns = ['START_HOUR_LOCAL', 'DAY_OF_WEEK_LOCAL', 'KO_TYPE', 
               'MTT_POOL_ALLOCATION_DESCRIPTION', 'ESTRUTURA_BLINDS']
encoded_columns = encoder.fit_transform(data_transform[cat_columns])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(cat_columns))
data_final = pd.concat([data_transform.drop(cat_columns, axis=1), encoded_df], axis=1)

X = data_final.drop(columns=['HAS_OVERLAY', 'OVERLAY', 'MTT_RESULT', 'COLLECTED', 'NORMALIZED_MTT_RESULT', 'NORMALIZED_COLLECTED' ], axis=1)
y = data_final['COLLECTED']

# %%
while current_date <= end_date:
    # Definir os períodos de treinamento e validação
    training_start = current_date - training_window
    training_end = current_date - pd.Timedelta(days=1)  # Um dia antes da validação
    validation_start = current_date
    validation_end = current_date + validation_window - pd.Timedelta(days=1)  # Último dia do mês

    # Filtrar os dados para treinamento e validação
    training_data = data_final[(data_final['START_DATE_LOCAL'] >= training_start) & (data_final['START_DATE_LOCAL'] <= training_end)]
    validation_data = data_final[(data_final['START_DATE_LOCAL'] >= validation_start) & (data_final['START_DATE_LOCAL'] <= validation_end)]

    # Aqui você pode treinar e validar o modelo
    print(f"Treinamento: {training_start.date()} a {training_end.date()}")
    print(f"Validação: {validation_start.date()} a {validation_end.date()}\n")

    # Avançar a janela para o próximo mês
    current_date += pd.DateOffset(months=1)
# Out:
# Treinamento: 2022-08-30 a 2023-07-29
# Validação: 2023-07-30 a 2023-08-29
#
# Treinamento: 2022-09-30 a 2023-08-29
# Validação: 2023-08-30 a 2023-09-29
#
# Treinamento: 2022-10-30 a 2023-09-29
# Validação: 2023-09-30 a 2023-10-29
#
# Treinamento: 2022-11-30 a 2023-10-29
# Validação: 2023-10-30 a 2023-11-29
#
# Treinamento: 2022-12-30 a 2023-11-29
# Validação: 2023-11-30 a 2023-12-29
#
# Treinamento: 2023-01-30 a 2023-12-29
# Validação: 2023-12-30 a 2024-01-29
#
# Treinamento: 2023-02-28 a 2024-01-29
# Validação: 2024-01-30 a 2024-02-28
#
# Treinamento: 2023-03-29 a 2024-02-28
# Validação: 2024-02-29 a 2024-03-28
#
# Treinamento: 2023-04-29 a 2024-03-28
# Validação: 2024-03-29 a 2024-04-28
#
# Treinamento: 2023-05-29 a 2024-04-28
# Validação: 2024-04-29 a 2024-05-28
#
# Treinamento: 2023-06-29 a 2024-05-28
# Validação: 2024-05-29 a 2024-06-28
#
# Treinamento: 2023-07-29 a 2024-06-28
# Validação: 2024-06-29 a 2024-07-28
#
# Treinamento: 2023-08-29 a 2024-07-28
# Validação: 2024-07-29 a 2024-08-28
#
# Treinamento: 2023-09-29 a 2024-08-28
# Validação: 2024-08-29 a 2024-09-28
#
# Treinamento: 2023-10-29 a 2024-09-28
# Validação: 2024-09-29 a 2024-10-28
#
# Treinamento: 2023-11-29 a 2024-10-28
# Validação: 2024-10-29 a 2024-11-28

# %%
# DEFINING THE CROSS-VALIDATION FUNCTION FOR XGBOOST REGRESSOR MODEL WITH OPTUNA
def cross_validation_optuna(trial, X, y, n_splits):
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 3, 20)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.8)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
    gamma = trial.suggest_float('gamma', 0, 5)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    reg_alpha = trial.suggest_float('reg_alpha', 1e-5, 1e1, log=True)
    reg_lambda = trial.suggest_float('reg_lambda', 1e-5, 1e1, log=True)


    model = xgb.XGBRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        gamma = gamma,
        min_child_weight = min_child_weight,
        reg_alpha = reg_alpha,
        reg_lambda = reg_lambda,
        device='cuda',
        random_state=42
    )

    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)

    results_list = []

    for train_idx, test_idx in kfold.split(X):
        X_train, X_test = X.iloc[train_idx, :], X.iloc[test_idx, :]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        model.fit(X_train, y_train)
        predictions = model.predict(X_test)

        # CREATION OF A DATAFRAME TO SAVE ALL THE RESULTS
        results_df = pd.DataFrame({
            'Actual': y_test,
            'Prediction': predictions,
        })

        # ADDING ADDITIONAL METRICS TO THE DATAFRAME
        results_df['Absolute difference'] = np.abs(results_df['Actual'] - results_df['Prediction'])
        results_df['Mean square difference'] = (results_df['Actual'] - results_df['Prediction']) ** 2
        results_df['Error percentage'] = (results_df['Actual'] - results_df['Prediction']) / results_df['Actual'] * 100
        results_df['Absolute error percentage'] = np.abs(results_df['Error percentage'])

        results_list.append(results_df)

    full_results_df = pd.concat(results_list, ignore_index=True)

    return full_results_df, model


# DEFINING THE OPTIMIZATION FUNCTION FOR HYPERPARAMETER TUNING
def optimize_hyperparameters(X, y):
    study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    def objective(trial):
        full_results_df, model = cross_validation_optuna(trial, X, y, n_splits=10)
        trial.set_user_attr("model", model)
        trial.set_user_attr("results", full_results_df)
        return full_results_df['Absolute difference'].median()  # Using MSE as the optimization target

    study.optimize(objective, n_trials=40)

    print("Best hyperparameters: ", study.best_params)

    best_trial = study.best_trial
    best_model = best_trial.user_attrs["model"]
    best_results = best_trial.user_attrs["results"]

    return best_model, best_results

# RUNNING THE MODEL 
best_model, best_results_df = optimize_hyperparameters(X, y)
# Out:
# [I 2024-11-19 16:08:08,266] A new study created in memory with name: no-name-47dfe1bd-2198-4035-bc20-1fed715fb3c0
# C:\Users\maiap\anaconda3\envs\suprema-env\lib\site-packages\xgboost\core.py:158: UserWarning: [16:08:09] WARNING: D:\bld\xgboost-split_1727635012356\work\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-19 16:08:15,937] Trial 0 finished with value: 35.31689453125 and parameters: {'n_estimators': 146, 'max_depth': 8, 'learning_rate': 0.46392456008558997, 'subsample': 0.8295531185538675, 'colsample_bytree': 0.5115167272086848, 'gamma': 0.043116108372410755, 'min_child_weight': 6, 'reg_alpha': 0.004871467304646351, 'reg_lambda': 0.003066405369570264}. Best is trial 0 with value: 35.31689453125.
# [I 2024-11-19 16:08:52,825] Trial 1 finished with value: 31.567446289062445 and parameters: {'n_estimators': 111, 'max_depth': 19, 'learning_rate': 0.5690463012097565, 'subsample': 0.7306962208926164, 'colsample_bytree': 0.8053797761251064, 'gamma': 4.263712670466595, 'min_child_weight': 1, 'reg_alpha': 0.00021439295213671213, 'reg_lambda': 2.2573160475956398}. Best is trial 1 with value: 31.567446289062445.
# [I 2024-11-19 16:09:45,825] Trial 2 finished with value: 31.058496093749994 and parameters: {'n_estimators': 199, 'max_depth': 17, 'learning_rate': 0.1787679055772448, 'subsample': 0.9473603847854215, 'colsample_bytree': 0.7371835510644207, 'gamma': 2.6136268747376294, 'min_child_weight': 2, 'reg_alpha': 0.021242267999411996, 'reg_lambda': 0.002099391663596536}. Best is trial 2 with value: 31.058496093749994.
# [I 2024-11-19 16:10:06,839] Trial 3 finished with value: 31.728125000000006 and parameters: {'n_estimators': 142, 'max_depth': 15, 'learning_rate': 0.2812333311514427, 'subsample': 0.5711285234530401, 'colsample_bytree': 0.6422508746778011, 'gamma': 3.490815588036051, 'min_child_weight': 2, 'reg_alpha': 0.0013226095688549343, 'reg_lambda': 0.00019255050449171814}. Best is trial 2 with value: 31.058496093749994.
# [I 2024-11-19 16:10:28,095] Trial 4 finished with value: 30.660488281249854 and parameters: {'n_estimators': 173, 'max_depth': 15, 'learning_rate': 0.09593671464861234, 'subsample': 0.6682995506832594, 'colsample_bytree': 0.919153200830406, 'gamma': 0.5127033012755949, 'min_child_weight': 9, 'reg_alpha': 0.016812985775762228, 'reg_lambda': 0.0040135638223231735}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:10:33,770] Trial 5 finished with value: 42.07157226562501 and parameters: {'n_estimators': 180, 'max_depth': 4, 'learning_rate': 0.3330150572843667, 'subsample': 0.522565295818689, 'colsample_bytree': 0.8413485898506832, 'gamma': 1.0267671552062025, 'min_child_weight': 2, 'reg_alpha': 0.0007402442108431389, 'reg_lambda': 0.000665216897035299}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:10:50,835] Trial 6 finished with value: 32.78786621093741 and parameters: {'n_estimators': 125, 'max_depth': 15, 'learning_rate': 0.7451281084903304, 'subsample': 0.8209950287228447, 'colsample_bytree': 0.6485937885427707, 'gamma': 3.040948289262209, 'min_child_weight': 3, 'reg_alpha': 9.384540674986443e-05, 'reg_lambda': 0.0020773084702321223}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:11:18,795] Trial 7 finished with value: 77.41118408203124 and parameters: {'n_estimators': 133, 'max_depth': 16, 'learning_rate': 0.02063495527780054, 'subsample': 0.8310530370632341, 'colsample_bytree': 0.5564716429211849, 'gamma': 4.258041544381608, 'min_child_weight': 8, 'reg_alpha': 0.00030612508135284647, 'reg_lambda': 0.03704794247459046}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:11:23,477] Trial 8 finished with value: 34.988505859374996 and parameters: {'n_estimators': 91, 'max_depth': 7, 'learning_rate': 0.15584751334350136, 'subsample': 0.9803415811000895, 'colsample_bytree': 0.8315931779087462, 'gamma': 4.052876493519078, 'min_child_weight': 6, 'reg_alpha': 0.6728696251325742, 'reg_lambda': 2.8258128507173818e-05}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:11:44,273] Trial 9 finished with value: 31.7105712890625 and parameters: {'n_estimators': 179, 'max_depth': 16, 'learning_rate': 0.46584777094956165, 'subsample': 0.7701925159334142, 'colsample_bytree': 0.9985059407514831, 'gamma': 3.3250651018040873, 'min_child_weight': 8, 'reg_alpha': 0.024847308377489188, 'reg_lambda': 0.0030658666963377696}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:11:50,133] Trial 10 finished with value: 566.349609375 and parameters: {'n_estimators': 59, 'max_depth': 11, 'learning_rate': 0.010358853585902675, 'subsample': 0.6484578210760618, 'colsample_bytree': 0.9929842961683161, 'gamma': 1.192054210200697, 'min_child_weight': 10, 'reg_alpha': 8.141013420030045, 'reg_lambda': 0.5031273095926071}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:12:39,793] Trial 11 finished with value: 31.164545898437495 and parameters: {'n_estimators': 197, 'max_depth': 20, 'learning_rate': 0.19031655951282567, 'subsample': 0.9846155637473041, 'colsample_bytree': 0.899397462623923, 'gamma': 1.9491497535464557, 'min_child_weight': 4, 'reg_alpha': 0.06407953262227208, 'reg_lambda': 0.05413391107856308}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:12:52,649] Trial 12 finished with value: 31.379724121093773 and parameters: {'n_estimators': 167, 'max_depth': 12, 'learning_rate': 0.18684925672889574, 'subsample': 0.6599332247211886, 'colsample_bytree': 0.7227037739137994, 'gamma': 2.2569514471043894, 'min_child_weight': 10, 'reg_alpha': 0.17612795122988203, 'reg_lambda': 9.849194820929975e-05}. Best is trial 4 with value: 30.660488281249854.
# [I 2024-11-19 16:13:12,866] Trial 13 finished with value: 30.652099609375 and parameters: {'n_estimators': 198, 'max_depth': 13, 'learning_rate': 0.13648274174700534, 'subsample': 0.9065857075862315, 'colsample_bytree': 0.7273895786466009, 'gamma': 0.2276693275649681, 'min_child_weight': 5, 'reg_alpha': 0.009237405256097354, 'reg_lambda': 0.03137953905391237}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:13:26,406] Trial 14 finished with value: 31.412036132812545 and parameters: {'n_estimators': 162, 'max_depth': 11, 'learning_rate': 0.07549780097541423, 'subsample': 0.8762419248840367, 'colsample_bytree': 0.9093935926039851, 'gamma': 0.006404549566409429, 'min_child_weight': 8, 'reg_alpha': 1.629740187695987e-05, 'reg_lambda': 0.04774053761589932}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:13:41,990] Trial 15 finished with value: 31.537268066406256 and parameters: {'n_estimators': 182, 'max_depth': 13, 'learning_rate': 0.3155638279824835, 'subsample': 0.6949428824708588, 'colsample_bytree': 0.6796256900880145, 'gamma': 0.8674539306937806, 'min_child_weight': 5, 'reg_alpha': 0.0035403230643943997, 'reg_lambda': 0.2756752189516513}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:13:50,892] Trial 16 finished with value: 32.90192382812501 and parameters: {'n_estimators': 156, 'max_depth': 9, 'learning_rate': 0.1061140347935359, 'subsample': 0.5635465758750972, 'colsample_bytree': 0.7818328050922063, 'gamma': 1.6694360195930806, 'min_child_weight': 7, 'reg_alpha': 0.6003226184476158, 'reg_lambda': 0.016913698217694055}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:14:08,918] Trial 17 finished with value: 31.254887695312505 and parameters: {'n_estimators': 199, 'max_depth': 13, 'learning_rate': 0.2574822824282524, 'subsample': 0.9057914925092331, 'colsample_bytree': 0.9062928499069044, 'gamma': 0.5005503923296362, 'min_child_weight': 4, 'reg_alpha': 0.008359223053323057, 'reg_lambda': 5.670405216120151}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:14:22,599] Trial 18 finished with value: 34.975815429687486 and parameters: {'n_estimators': 97, 'max_depth': 18, 'learning_rate': 0.6030925183304224, 'subsample': 0.6158159934217329, 'colsample_bytree': 0.5891184598863134, 'gamma': 1.6192734100429405, 'min_child_weight': 9, 'reg_alpha': 0.17939092665871212, 'reg_lambda': 0.21336181658194583}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:14:28,930] Trial 19 finished with value: 38.685791015625 and parameters: {'n_estimators': 173, 'max_depth': 5, 'learning_rate': 0.39661502429332485, 'subsample': 0.7676761345830312, 'colsample_bytree': 0.7025390731246737, 'gamma': 4.895823954213509, 'min_child_weight': 5, 'reg_alpha': 7.840264382577582, 'reg_lambda': 1.212700497203917e-05}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:14:40,299] Trial 20 finished with value: 32.01182861328124 and parameters: {'n_estimators': 52, 'max_depth': 14, 'learning_rate': 0.09039636747283267, 'subsample': 0.7177952903252307, 'colsample_bytree': 0.9469654193253995, 'gamma': 0.5399329710453988, 'min_child_weight': 7, 'reg_alpha': 0.0014901012343060064, 'reg_lambda': 0.008355378163513475}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:15:44,123] Trial 21 finished with value: 31.54193115234375 and parameters: {'n_estimators': 192, 'max_depth': 17, 'learning_rate': 0.20547900030870755, 'subsample': 0.9227185119482242, 'colsample_bytree': 0.7578195276748814, 'gamma': 2.5642072348963723, 'min_child_weight': 1, 'reg_alpha': 0.023676583223001514, 'reg_lambda': 0.000583079186452761}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:16:26,097] Trial 22 finished with value: 30.746240234375023 and parameters: {'n_estimators': 187, 'max_depth': 17, 'learning_rate': 0.15009759147744023, 'subsample': 0.9283063351285327, 'colsample_bytree': 0.744593724700124, 'gamma': 2.7085848564397708, 'min_child_weight': 3, 'reg_alpha': 0.02331012659842151, 'reg_lambda': 0.010558094427016504}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:16:36,759] Trial 23 finished with value: 31.859936523437497 and parameters: {'n_estimators': 154, 'max_depth': 10, 'learning_rate': 0.1080095635559204, 'subsample': 0.8715877444539388, 'colsample_bytree': 0.861192595006751, 'gamma': 0.4819720309933441, 'min_child_weight': 4, 'reg_alpha': 0.08213086606008957, 'reg_lambda': 0.011131947006943517}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:16:58,648] Trial 24 finished with value: 30.86302734375022 and parameters: {'n_estimators': 183, 'max_depth': 14, 'learning_rate': 0.25991180170150807, 'subsample': 0.7922590489652206, 'colsample_bytree': 0.7777856944746852, 'gamma': 1.4093170737262142, 'min_child_weight': 3, 'reg_alpha': 0.6130255983448603, 'reg_lambda': 0.1043944641401747}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:17:45,677] Trial 25 finished with value: 30.710913085937477 and parameters: {'n_estimators': 168, 'max_depth': 18, 'learning_rate': 0.051670108048981866, 'subsample': 0.8794305325864308, 'colsample_bytree': 0.6599330031912156, 'gamma': 2.0372684169895283, 'min_child_weight': 5, 'reg_alpha': 0.010783926476033894, 'reg_lambda': 0.007941335205283402}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:18:35,693] Trial 26 finished with value: 30.678684082031225 and parameters: {'n_estimators': 171, 'max_depth': 19, 'learning_rate': 0.045888727056799195, 'subsample': 0.8577544497682352, 'colsample_bytree': 0.6410069896130957, 'gamma': 0.7520222813599344, 'min_child_weight': 6, 'reg_alpha': 0.003793066527074931, 'reg_lambda': 0.000767411014014418}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:19:04,707] Trial 27 finished with value: 30.962172851562627 and parameters: {'n_estimators': 142, 'max_depth': 19, 'learning_rate': 0.12180524537971571, 'subsample': 0.6829516638135604, 'colsample_bytree': 0.5825618699344963, 'gamma': 0.7585947482522435, 'min_child_weight': 7, 'reg_alpha': 0.0026767996337057134, 'reg_lambda': 0.000758377353233814}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:19:52,381] Trial 28 finished with value: 96.1518310546875 and parameters: {'n_estimators': 154, 'max_depth': 20, 'learning_rate': 0.016088413853176813, 'subsample': 0.6111658980502779, 'colsample_bytree': 0.6056713222204135, 'gamma': 0.21758538114368287, 'min_child_weight': 9, 'reg_alpha': 4.7727977478748834e-05, 'reg_lambda': 0.0002547211590188442}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:20:01,196] Trial 29 finished with value: 34.1727294921875 and parameters: {'n_estimators': 172, 'max_depth': 8, 'learning_rate': 0.37176641188581827, 'subsample': 0.8265465216438461, 'colsample_bytree': 0.5192053010341446, 'gamma': 0.26011217138358844, 'min_child_weight': 6, 'reg_alpha': 0.008016912863845576, 'reg_lambda': 7.04302087973765e-05}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:20:08,925] Trial 30 finished with value: 31.978979492187506 and parameters: {'n_estimators': 73, 'max_depth': 13, 'learning_rate': 0.46306250399815796, 'subsample': 0.9537137929883818, 'colsample_bytree': 0.7042299383278111, 'gamma': 1.2383943698591515, 'min_child_weight': 9, 'reg_alpha': 0.0004684915573834072, 'reg_lambda': 0.9681914819912911}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:20:54,120] Trial 31 finished with value: 30.737353515625045 and parameters: {'n_estimators': 166, 'max_depth': 18, 'learning_rate': 0.06465219413580864, 'subsample': 0.8737660133850815, 'colsample_bytree': 0.6517802833258461, 'gamma': 1.9321384161152177, 'min_child_weight': 5, 'reg_alpha': 0.004476197592338777, 'reg_lambda': 0.005275181834159584}. Best is trial 13 with value: 30.652099609375.
# [I 2024-11-19 16:21:48,354] Trial 32 finished with value: 30.606054687500006 and parameters: {'n_estimators': 190, 'max_depth': 19, 'learning_rate': 0.05286176186522758, 'subsample': 0.8972492885301128, 'colsample_bytree': 0.6239232085767579, 'gamma': 0.7738235814613215, 'min_child_weight': 6, 'reg_alpha': 0.010347827335357194, 'reg_lambda': 0.0015569238616709058}. Best is trial 32 with value: 30.606054687500006.
# [I 2024-11-19 16:22:26,553] Trial 33 finished with value: 31.341816406250018 and parameters: {'n_estimators': 188, 'max_depth': 19, 'learning_rate': 0.22200716634539386, 'subsample': 0.8491939000155435, 'colsample_bytree': 0.6280650053013844, 'gamma': 0.8200403045914324, 'min_child_weight': 6, 'reg_alpha': 0.06467482257845372, 'reg_lambda': 0.001233404954703961}. Best is trial 32 with value: 30.606054687500006.
# [I 2024-11-19 16:22:52,670] Trial 34 finished with value: 31.067846679687506 and parameters: {'n_estimators': 196, 'max_depth': 15, 'learning_rate': 0.13736857794664092, 'subsample': 0.7390298159643154, 'colsample_bytree': 0.5570784259815532, 'gamma': 0.32957395867995565, 'min_child_weight': 7, 'reg_alpha': 0.0022141915686296238, 'reg_lambda': 0.00030127156227157065}. Best is trial 32 with value: 30.606054687500006.
# [I 2024-11-19 16:23:19,659] Trial 35 finished with value: 30.29340820312501 and parameters: {'n_estimators': 110, 'max_depth': 16, 'learning_rate': 0.06816448127304066, 'subsample': 0.9112424040826942, 'colsample_bytree': 0.6819324010072926, 'gamma': 0.016392012530653144, 'min_child_weight': 6, 'reg_alpha': 0.0007971807194501131, 'reg_lambda': 0.02278351502837931}. Best is trial 35 with value: 30.29340820312501.
# [I 2024-11-19 16:23:37,028] Trial 36 finished with value: 32.27032470703125 and parameters: {'n_estimators': 110, 'max_depth': 16, 'learning_rate': 0.7620987728132099, 'subsample': 0.9994472028525541, 'colsample_bytree': 0.6882649901332002, 'gamma': 0.020777738025011594, 'min_child_weight': 4, 'reg_alpha': 0.0008141875464394583, 'reg_lambda': 0.025086440901756334}. Best is trial 35 with value: 30.29340820312501.
# [I 2024-11-19 16:23:51,593] Trial 37 finished with value: 30.88124999999991 and parameters: {'n_estimators': 125, 'max_depth': 14, 'learning_rate': 0.2382505203607191, 'subsample': 0.9539576098696396, 'colsample_bytree': 0.8137818454378913, 'gamma': 0.5793964919721221, 'min_child_weight': 8, 'reg_alpha': 0.00014052522187335756, 'reg_lambda': 0.003909900870174433}. Best is trial 35 with value: 30.29340820312501.
# [I 2024-11-19 16:24:08,648] Trial 38 finished with value: 30.707167968750014 and parameters: {'n_estimators': 109, 'max_depth': 15, 'learning_rate': 0.1605236183241826, 'subsample': 0.9075420256938382, 'colsample_bytree': 0.7237077957895354, 'gamma': 1.115420057171289, 'min_child_weight': 7, 'reg_alpha': 0.011369299135174659, 'reg_lambda': 0.0018718047060143576}. Best is trial 35 with value: 30.29340820312501.
# [I 2024-11-19 16:24:20,271] Trial 39 finished with value: 32.78240722656233 and parameters: {'n_estimators': 133, 'max_depth': 12, 'learning_rate': 0.626227130732499, 'subsample': 0.7866564308280664, 'colsample_bytree': 0.6192413111093725, 'gamma': 0.20228503805574535, 'min_child_weight': 5, 'reg_alpha': 0.0008037558867322178, 'reg_lambda': 0.0920937707315776}. Best is trial 35 with value: 30.29340820312501.
# Best hyperparameters:  {'n_estimators': 110, 'max_depth': 16, 'learning_rate': 0.06816448127304066, 'subsample': 0.9112424040826942, 'colsample_bytree': 0.6819324010072926, 'gamma': 0.016392012530653144, 'min_child_weight': 6, 'reg_alpha': 0.0007971807194501131, 'reg_lambda': 0.02278351502837931}

# %%
# SAVING THE MODEL AND THE ENCODER
joblib.dump(encoder, '../new_model/history_encoder.pkl')
joblib.dump(best_model, '../new_model/history_model.pkl')
# Out:
# ['../new_model/history_model.pkl']

# %%
# ENCODING CATEGORICAL COLUMNS AND DEFINING X AND Y
encoder = OneHotEncoder(sparse_output=False)
data_transform = data.drop(columns=['MATCH_ID', 'START_DATE_LOCAL'])
cat_columns = ['START_HOUR_LOCAL', 'DAY_OF_WEEK_LOCAL', 'KO_TYPE', 
               'MTT_POOL_ALLOCATION_DESCRIPTION', 'ESTRUTURA_BLINDS']
encoded_columns = encoder.fit_transform(data_transform[cat_columns])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(cat_columns))
data_final = pd.concat([data_transform.drop(cat_columns, axis=1), encoded_df], axis=1)

X = data_final.drop(columns=['HAS_OVERLAY', 'OVERLAY', 'MTT_RESULT', 'COLLECTED', 'NORMALIZED_MTT_RESULT', 'NORMALIZED_COLLECTED' ], axis=1)
y = data_final['COLLECTED']

# %%
from sklearn.model_selection import TimeSeriesSplit

# FUNÇÃO DE VALIDAÇÃO CRUZADA PARA XGBOOST COM JANELA DESLIZANTE
def cross_validation_optuna_time_series(trial, X, y, train_months, test_months):
    # Sugerindo hiperparâmetros
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    max_depth = trial.suggest_int('max_depth', 3, 20)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.8)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
    gamma = trial.suggest_float('gamma', 0, 5)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    reg_alpha = trial.suggest_float('reg_alpha', 1e-5, 1e1, log=True)
    reg_lambda = trial.suggest_float('reg_lambda', 1e-5, 1e1, log=True)

    # Inicializando o modelo
    model = xgb.XGBRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        gamma=gamma,
        min_child_weight=min_child_weight,
        reg_alpha=reg_alpha,
        reg_lambda=reg_lambda,
        device='cuda',
        random_state=42
    )

    # Configurando a validação temporal com janela deslizante
    tscv = TimeSeriesSplit(gap=0, test_size=test_months, train_size=train_months)
    results_list = []

    for train_idx, test_idx in tscv.split(X):
        X_train, X_test = X.iloc[train_idx, :], X.iloc[test_idx, :]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        model.fit(X_train, y_train)
        predictions = model.predict(X_test)

        # Criando um DataFrame para salvar os resultados
        results_df = pd.DataFrame({
            'Actual': y_test,
            'Prediction': predictions,
        })

        # Adicionando métricas ao DataFrame
        results_df['Absolute difference'] = np.abs(results_df['Actual'] - results_df['Prediction'])
        results_df['Mean square difference'] = (results_df['Actual'] - results_df['Prediction']) ** 2
        results_df['Error percentage'] = (results_df['Actual'] - results_df['Prediction']) / results_df['Actual'] * 100
        results_df['Absolute error percentage'] = np.abs(results_df['Error percentage'])

        results_list.append(results_df)

    # Consolidando os resultados
    full_results_df = pd.concat(results_list, ignore_index=True)

    return full_results_df, model

# ALTERANDO A FUNÇÃO DE OTIMIZAÇÃO PARA UTILIZAR A VALIDAÇÃO TEMPORAL
def optimize_hyperparameters_time_series(X, y):
    study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    def objective(trial):
        # Usando 11 meses para treinamento e 1 mês para validação
        full_results_df, model = cross_validation_optuna_time_series(trial, X, y, train_months=11, test_months=1)
        trial.set_user_attr("model", model)
        trial.set_user_attr("results", full_results_df)
        return full_results_df['Absolute difference'].median()  # Usando o erro absoluto mediano como métrica de otimização

    study.optimize(objective, n_trials=40)

    print("Best hyperparameters: ", study.best_params)

    best_trial = study.best_trial
    best_model = best_trial.user_attrs["model"]
    best_results = best_trial.user_attrs["results"]

    return best_model, best_results

# EXECUTANDO A OTIMIZAÇÃO
best_model, best_results_df = optimize_hyperparameters_time_series(X, y)

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
import optuna
import pickle

# Encoding das colunas categóricas
encoder = OneHotEncoder(sparse_output=False)
data_transform = data.drop(columns=['MATCH_ID'])
cat_columns = ['START_HOUR_LOCAL', 'DAY_OF_WEEK_LOCAL', 'KO_TYPE', 
               'MTT_POOL_ALLOCATION_DESCRIPTION', 'ESTRUTURA_BLINDS']
encoded_columns = encoder.fit_transform(data_transform[cat_columns])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(cat_columns))
data_final = pd.concat([data_transform.drop(cat_columns, axis=1), encoded_df], axis=1)

# Preparar X e y
X = data_final.drop(columns=['HAS_OVERLAY', 'OVERLAY', 'MTT_RESULT', 'COLLECTED', 'NORMALIZED_MTT_RESULT', 
                             'NORMALIZED_COLLECTED', 'START_DATE_LOCAL'], axis=1)  # Remove a coluna de data aqui
y = data_final['COLLECTED']

# Função para otimizar hiperparâmetros
def optimize_hyperparameters(X_train, y_train, period_label):
    study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(), pruner=optuna.pruners.MedianPruner())

    def objective(trial):
        # Hiperparâmetros
        n_estimators = trial.suggest_int('n_estimators', 50, 200)
        max_depth = trial.suggest_int('max_depth', 3, 20)
        learning_rate = trial.suggest_float('learning_rate', 0.01, 0.8)
        subsample = trial.suggest_float('subsample', 0.5, 1.0)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1.0)
        gamma = trial.suggest_float('gamma', 0, 5)
        min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
        reg_alpha = trial.suggest_float('reg_alpha', 1e-5, 1e1, log=True)
        reg_lambda = trial.suggest_float('reg_lambda', 1e-5, 1e1, log=True)

        model = xgb.XGBRegressor(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            subsample=subsample,
            colsample_bytree=colsample_bytree,
            gamma=gamma,
            min_child_weight=min_child_weight,
            reg_alpha=reg_alpha,
            reg_lambda=reg_lambda,
            device='cuda',
            random_state=42
        )

        kfold = KFold(n_splits=5, shuffle=True, random_state=42)
        scores = []

        for train_idx, test_idx in kfold.split(X_train):
            X_train_fold, X_test_fold = X_train.iloc[train_idx], X_train.iloc[test_idx]
            y_train_fold, y_test_fold = y_train.iloc[train_idx], y_train.iloc[test_idx]

            model.fit(X_train_fold, y_train_fold)
            predictions = model.predict(X_test_fold)

            # Mean Absolute Error como métrica
            mae = np.mean(np.abs(predictions - y_test_fold))
            scores.append(mae)

        return np.mean(scores)

    # Rodar a otimização
    study.optimize(objective, n_trials=40)

    # Treinar modelo final com os melhores hiperparâmetros
    best_params = study.best_params
    final_model = xgb.XGBRegressor(**best_params, device='cuda', random_state=42)
    final_model.fit(X_train, y_train)

    # Salvar o modelo
    filename = f"xgb_model_{period_label}.pkl"
    with open(filename, "wb") as file:
        pickle.dump(final_model, file)
    print(f"Modelo salvo como: {filename}")

    return final_model

# Loop temporal
data_final['START_DATE_LOCAL'] = pd.to_datetime(data_final['START_DATE_LOCAL'])
training_window = pd.DateOffset(months=11)
validation_window = pd.DateOffset(months=1)
start_date = pd.to_datetime('2023-07-30')
end_date = pd.Timestamp(pd.Timestamp.now() - pd.DateOffset(days=1))

current_date = start_date

while current_date <= end_date:
    # Definir janelas de treinamento e validação
    training_start = current_date - training_window
    training_end = current_date - pd.Timedelta(days=1)
    validation_start = current_date
    validation_end = current_date + validation_window - pd.Timedelta(days=1)

    training_data = data_final[(data_final['START_DATE_LOCAL'] >= training_start) & (data_final['START_DATE_LOCAL'] <= training_end)]
    validation_data = data_final[(data_final['START_DATE_LOCAL'] >= validation_start) & (data_final['START_DATE_LOCAL'] <= validation_end)]

    X_train = training_data.drop(columns=['COLLECTED', 'START_DATE_LOCAL'])  # Certifique-se de excluir a coluna de data
    y_train = training_data['COLLECTED']

    X_valid = validation_data.drop(columns=['COLLECTED', 'START_DATE_LOCAL'])
    y_valid = validation_data['COLLECTED']

    # Nome do período atual
    period_label = f"{training_start.date()}_to_{validation_end.date()}"

    # Otimizar os hiperparâmetros para a janela atual
    print(f"Tunando hiperparâmetros para período de {training_start.date()} a {validation_end.date()}")
    best_model = optimize_hyperparameters(X_train, y_train, period_label)

    # Avançar janela
    current_date += pd.DateOffset(months=1)
# Out:
# [I 2024-11-29 12:15:48,186] A new study created in memory with name: no-name-294d6558-4806-4d22-9b2e-590b73c2a5d7
# Tunando hiperparâmetros para período de 2022-08-30 a 2023-08-29
# C:\Users\maiap\anaconda3\envs\suprema-env\lib\site-packages\xgboost\core.py:158: UserWarning: [12:15:49] WARNING: D:\bld\xgboost-split_1727635012356\work\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# [I 2024-11-29 12:15:52,761] Trial 0 finished with value: 21.579745441040927 and parameters: {'n_estimators': 198, 'max_depth': 7, 'learning_rate': 0.5463167860909405, 'subsample': 0.8100166315977635, 'colsample_bytree': 0.8798264524073864, 'gamma': 1.869642262935295, 'min_child_weight': 3, 'reg_alpha': 0.00034043266433635773, 'reg_lambda': 0.001020651318136569}. Best is trial 0 with value: 21.579745441040927.
# [I 2024-11-29 12:15:58,183] Trial 1 finished with value: 35.23490359462781 and parameters: {'n_estimators': 174, 'max_depth': 10, 'learning_rate': 0.7106960124857787, 'subsample': 0.7574584065703855, 'colsample_bytree': 0.7585999036929796, 'gamma': 1.0453994809155576, 'min_child_weight': 2, 'reg_alpha': 3.533827559396275e-05, 'reg_lambda': 0.5536480005700402}. Best is trial 0 with value: 21.579745441040927.
# [I 2024-11-29 12:16:00,691] Trial 2 finished with value: 54.431184290833606 and parameters: {'n_estimators': 142, 'max_depth': 6, 'learning_rate': 0.7623874517021532, 'subsample': 0.5868762275575421, 'colsample_bytree': 0.639336258280307, 'gamma': 0.48701006352859455, 'min_child_weight': 5, 'reg_alpha': 0.00018910606577901158, 'reg_lambda': 0.0018130747017507793}. Best is trial 0 with value: 21.579745441040927.
# [I 2024-11-29 12:16:02,307] Trial 3 finished with value: 20.8884874742789 and parameters: {'n_estimators': 62, 'max_depth': 7, 'learning_rate': 0.3698481421249004, 'subsample': 0.567329713911211, 'colsample_bytree': 0.9226921390432937, 'gamma': 4.152352862423871, 'min_child_weight': 1, 'reg_alpha': 0.05585842791287495, 'reg_lambda': 5.337214042870845e-05}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:07,351] Trial 4 finished with value: 39.562814314999166 and parameters: {'n_estimators': 132, 'max_depth': 14, 'learning_rate': 0.3577496689307914, 'subsample': 0.6276356114316806, 'colsample_bytree': 0.7367376194330988, 'gamma': 0.2501368751071653, 'min_child_weight': 9, 'reg_alpha': 0.36479985139845406, 'reg_lambda': 0.0014193599323691676}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:10,969] Trial 5 finished with value: 35.20196784927761 and parameters: {'n_estimators': 137, 'max_depth': 9, 'learning_rate': 0.32290149716210753, 'subsample': 0.5583764766538049, 'colsample_bytree': 0.5992894641110887, 'gamma': 1.6026164743657778, 'min_child_weight': 3, 'reg_alpha': 2.4000546128364473e-05, 'reg_lambda': 1.2291722081201444}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:13,954] Trial 6 finished with value: 26.773136138976533 and parameters: {'n_estimators': 60, 'max_depth': 18, 'learning_rate': 0.5091434435568872, 'subsample': 0.6866267065268935, 'colsample_bytree': 0.932219031023807, 'gamma': 0.6374241103881723, 'min_child_weight': 10, 'reg_alpha': 0.01077062224780007, 'reg_lambda': 0.0696864812865009}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:18,061] Trial 7 finished with value: 59.38219402144307 and parameters: {'n_estimators': 191, 'max_depth': 7, 'learning_rate': 0.4585063301611971, 'subsample': 0.5092305526740318, 'colsample_bytree': 0.5167068445818357, 'gamma': 1.2658361409631813, 'min_child_weight': 4, 'reg_alpha': 1.0121486423474074e-05, 'reg_lambda': 0.0007566173756449677}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:22,037] Trial 8 finished with value: 38.7788174828569 and parameters: {'n_estimators': 58, 'max_depth': 13, 'learning_rate': 0.33249530088825924, 'subsample': 0.8657926656557011, 'colsample_bytree': 0.565006839165509, 'gamma': 3.869680614818311, 'min_child_weight': 2, 'reg_alpha': 1.154623856225512e-05, 'reg_lambda': 0.0034043369998489332}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:24,155] Trial 9 finished with value: 61.375921873225025 and parameters: {'n_estimators': 66, 'max_depth': 10, 'learning_rate': 0.6363412741380235, 'subsample': 0.5093066828179795, 'colsample_bytree': 0.5422648133236021, 'gamma': 1.358517207054966, 'min_child_weight': 4, 'reg_alpha': 0.0546125926296046, 'reg_lambda': 0.0004262524175139561}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:25,713] Trial 10 finished with value: 30.737166694636073 and parameters: {'n_estimators': 92, 'max_depth': 4, 'learning_rate': 0.06193494473593386, 'subsample': 0.9936000825070139, 'colsample_bytree': 0.9634427683513406, 'gamma': 4.852109687040678, 'min_child_weight': 8, 'reg_alpha': 4.851621785728852, 'reg_lambda': 1.3726094368889719e-05}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:27,284] Trial 11 finished with value: 27.68624092032464 and parameters: {'n_estimators': 101, 'max_depth': 3, 'learning_rate': 0.19048156684939216, 'subsample': 0.8110375907187528, 'colsample_bytree': 0.8505867236405622, 'gamma': 2.986086548211193, 'min_child_weight': 1, 'reg_alpha': 0.000625693402405092, 'reg_lambda': 4.675707827930232e-05}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:16:59,219] Trial 12 finished with value: 27.991266469407066 and parameters: {'n_estimators': 164, 'max_depth': 7, 'learning_rate': 0.6179325324975427, 'subsample': 0.8975197947154927, 'colsample_bytree': 0.8739592313351253, 'gamma': 2.556518447759942, 'min_child_weight': 7, 'reg_alpha': 0.0023173710767812727, 'reg_lambda': 0.0001281207183193859}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:17:22,599] Trial 13 finished with value: 24.466571996634634 and parameters: {'n_estimators': 106, 'max_depth': 5, 'learning_rate': 0.5289791886329986, 'subsample': 0.6901767163220588, 'colsample_bytree': 0.996991541263982, 'gamma': 3.8316527623483605, 'min_child_weight': 1, 'reg_alpha': 0.12536053895919883, 'reg_lambda': 0.031386579865092}. Best is trial 3 with value: 20.8884874742789.
# [I 2024-11-29 12:17:32,744] Trial 14 finished with value: 18.33644542851924 and parameters: {'n_estimators': 195, 'max_depth': 16, 'learning_rate': 0.22507751422030803, 'subsample': 0.7654832722388546, 'colsample_bytree': 0.8525557346751043, 'gamma': 2.0577437798456817, 'min_child_weight': 6, 'reg_alpha': 0.008310714362352587, 'reg_lambda': 9.701538610003522e-05}. Best is trial 14 with value: 18.33644542851924.
# [I 2024-11-29 12:17:37,644] Trial 15 finished with value: 18.493113765013113 and parameters: {'n_estimators': 82, 'max_depth': 18, 'learning_rate': 0.20508486479334292, 'subsample': 0.6832904685250814, 'colsample_bytree': 0.7950914755550978, 'gamma': 3.470143526723036, 'min_child_weight': 6, 'reg_alpha': 0.012962359772721213, 'reg_lambda': 1.0470972805775865e-05}. Best is trial 14 with value: 18.33644542851924.
# [I 2024-11-29 12:17:43,187] Trial 16 finished with value: 18.655463505898105 and parameters: {'n_estimators': 84, 'max_depth': 20, 'learning_rate': 0.20036229278897236, 'subsample': 0.6830933305648197, 'colsample_bytree': 0.7798356795621599, 'gamma': 2.655044343418529, 'min_child_weight': 6, 'reg_alpha': 0.004435013606784844, 'reg_lambda': 1.9606274599137684e-05}. Best is trial 14 with value: 18.33644542851924.
# [I 2024-11-29 12:17:48,369] Trial 17 finished with value: 24.842334858956754 and parameters: {'n_estimators': 115, 'max_depth': 16, 'learning_rate': 0.05131151007147616, 'subsample': 0.7498380303020474, 'colsample_bytree': 0.7085109640095302, 'gamma': 3.3088996026353534, 'min_child_weight': 6, 'reg_alpha': 1.4069278290061091, 'reg_lambda': 6.548704530689698}. Best is trial 14 with value: 18.33644542851924.
# [I 2024-11-29 12:17:55,533] Trial 18 finished with value: 19.373495511394733 and parameters: {'n_estimators': 155, 'max_depth': 16, 'learning_rate': 0.19235106991779846, 'subsample': 0.7400428656325416, 'colsample_bytree': 0.826006354885949, 'gamma': 2.0722812340504877, 'min_child_weight': 8, 'reg_alpha': 0.013867255087643393, 'reg_lambda': 0.00018929897289694212}. Best is trial 14 with value: 18.33644542851924.
# [I 2024-11-29 12:18:00,299] Trial 19 finished with value: 34.261970804460304 and parameters: {'n_estimators': 77, 'max_depth': 20, 'learning_rate': 0.26251180084053116, 'subsample': 0.6390559600718468, 'colsample_bytree': 0.6957294141121226, 'gamma': 3.378280173630963, 'min_child_weight': 7, 'reg_alpha': 0.0013554216227711332, 'reg_lambda': 1.0232030957228134e-05}. Best is trial 14 with value: 18.33644542851924.
# [I 2024-11-29 12:18:10,215] Trial 20 finished with value: 16.901594011890438 and parameters: {'n_estimators': 180, 'max_depth': 17, 'learning_rate': 0.11468487607477774, 'subsample': 0.9393731584162774, 'colsample_bytree': 0.8067097458411986, 'gamma': 4.778907946791305, 'min_child_weight': 5, 'reg_alpha': 0.02411587132802301, 'reg_lambda': 0.011856352365515722}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:18:20,145] Trial 21 finished with value: 17.015789415075854 and parameters: {'n_estimators': 180, 'max_depth': 17, 'learning_rate': 0.11249142482190866, 'subsample': 0.9515154972634794, 'colsample_bytree': 0.8142792524633644, 'gamma': 4.990480347641535, 'min_child_weight': 5, 'reg_alpha': 0.02098524543730297, 'reg_lambda': 0.01076691056167115}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:18:29,506] Trial 22 finished with value: 17.083039510118038 and parameters: {'n_estimators': 183, 'max_depth': 16, 'learning_rate': 0.11251280105123186, 'subsample': 0.9932167187248448, 'colsample_bytree': 0.8213389239569764, 'gamma': 4.99010507625107, 'min_child_weight': 5, 'reg_alpha': 0.052961421606074546, 'reg_lambda': 0.013885305258411113}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:18:37,805] Trial 23 finished with value: 17.27972870958206 and parameters: {'n_estimators': 178, 'max_depth': 14, 'learning_rate': 0.10699020356555061, 'subsample': 0.9914406641971265, 'colsample_bytree': 0.8245901165896974, 'gamma': 4.79676894046352, 'min_child_weight': 5, 'reg_alpha': 0.4576726819098418, 'reg_lambda': 0.012938753715205501}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:18:47,691] Trial 24 finished with value: 23.890849942264698 and parameters: {'n_estimators': 181, 'max_depth': 17, 'learning_rate': 0.12410822343744787, 'subsample': 0.9379381505584065, 'colsample_bytree': 0.6686279392893942, 'gamma': 4.419552610953674, 'min_child_weight': 4, 'reg_alpha': 0.049943041198722386, 'reg_lambda': 0.10837303627478488}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:19:00,237] Trial 25 finished with value: 270.7464012802135 and parameters: {'n_estimators': 154, 'max_depth': 13, 'learning_rate': 0.010614576208583568, 'subsample': 0.9424028830145165, 'colsample_bytree': 0.7957722354185754, 'gamma': 4.992752074286107, 'min_child_weight': 5, 'reg_alpha': 0.19733941307006256, 'reg_lambda': 0.006246877804042445}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:19:08,181] Trial 26 finished with value: 18.143657019373762 and parameters: {'n_estimators': 166, 'max_depth': 19, 'learning_rate': 0.14072642221860748, 'subsample': 0.9435345312070655, 'colsample_bytree': 0.9061918886480853, 'gamma': 4.462612941832614, 'min_child_weight': 7, 'reg_alpha': 1.5118543495521204, 'reg_lambda': 0.01666779372864632}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:19:19,583] Trial 27 finished with value: 215.4488149165565 and parameters: {'n_estimators': 186, 'max_depth': 15, 'learning_rate': 0.010093946960575834, 'subsample': 0.8676816365248959, 'colsample_bytree': 0.7311845434857447, 'gamma': 4.4909679646385, 'min_child_weight': 4, 'reg_alpha': 0.023919355988273754, 'reg_lambda': 0.15061534246885266}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:19:25,091] Trial 28 finished with value: 18.458061178929746 and parameters: {'n_estimators': 149, 'max_depth': 12, 'learning_rate': 0.2657095724674002, 'subsample': 0.9071780129287228, 'colsample_bytree': 0.8197748725422663, 'gamma': 3.9500561224102304, 'min_child_weight': 5, 'reg_alpha': 0.004235799982372287, 'reg_lambda': 0.037931170694743284}. Best is trial 20 with value: 16.901594011890438.
# [I 2024-11-29 12:19:36,767] Trial 29 finished with value: 14.3085909297159 and parameters: {'n_estimators': 200, 'max_depth': 18, 'learning_rate': 0.09898005730272069, 'subsample': 0.9780435721441594, 'colsample_bytree': 0.8889989962297085, 'gamma': 4.592987552011662, 'min_child_weight': 3, 'reg_alpha': 0.00016666730147946038, 'reg_lambda': 0.34607884372918335}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:19:44,154] Trial 30 finished with value: 16.827315706423242 and parameters: {'n_estimators': 199, 'max_depth': 18, 'learning_rate': 0.4234413366720183, 'subsample': 0.8469620219554815, 'colsample_bytree': 0.8957968931725327, 'gamma': 4.304449957617059, 'min_child_weight': 3, 'reg_alpha': 0.00010140046693750466, 'reg_lambda': 0.3528454841930596}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:19:51,412] Trial 31 finished with value: 18.06430825359902 and parameters: {'n_estimators': 194, 'max_depth': 18, 'learning_rate': 0.4727663807779239, 'subsample': 0.8290266154557167, 'colsample_bytree': 0.8879142536698353, 'gamma': 4.268583863408417, 'min_child_weight': 3, 'reg_alpha': 0.0001280824251180055, 'reg_lambda': 0.44140817839000474}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:19:59,143] Trial 32 finished with value: 16.670992768241646 and parameters: {'n_estimators': 198, 'max_depth': 19, 'learning_rate': 0.4134260591423888, 'subsample': 0.958638499527625, 'colsample_bytree': 0.8636902405213558, 'gamma': 4.630721812816359, 'min_child_weight': 3, 'reg_alpha': 0.00013083385437944196, 'reg_lambda': 3.187116223107997}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:20:07,473] Trial 33 finished with value: 17.638700460914265 and parameters: {'n_estimators': 200, 'max_depth': 19, 'learning_rate': 0.442199629343024, 'subsample': 0.902675698134962, 'colsample_bytree': 0.9558831844049596, 'gamma': 4.5381217642201275, 'min_child_weight': 3, 'reg_alpha': 0.0001255752549528856, 'reg_lambda': 4.900266949470709}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:20:14,563] Trial 34 finished with value: 16.334808654744812 and parameters: {'n_estimators': 170, 'max_depth': 19, 'learning_rate': 0.4040949083685238, 'subsample': 0.8527949825574593, 'colsample_bytree': 0.8683591701262698, 'gamma': 4.077907717376884, 'min_child_weight': 2, 'reg_alpha': 5.644688474176318e-05, 'reg_lambda': 1.7350770449581914}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:20:21,563] Trial 35 finished with value: 17.45923431852332 and parameters: {'n_estimators': 169, 'max_depth': 20, 'learning_rate': 0.3963198871740697, 'subsample': 0.8466361945257803, 'colsample_bytree': 0.8696367322412549, 'gamma': 3.633066067937034, 'min_child_weight': 2, 'reg_alpha': 5.461747861907696e-05, 'reg_lambda': 2.1094304110694337}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:20:27,984] Trial 36 finished with value: 19.725036564617067 and parameters: {'n_estimators': 199, 'max_depth': 19, 'learning_rate': 0.5892426664809942, 'subsample': 0.7822758585635993, 'colsample_bytree': 0.9125914015159101, 'gamma': 4.043002949874401, 'min_child_weight': 2, 'reg_alpha': 0.0003957540302568588, 'reg_lambda': 0.4008700627370263}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:20:33,834] Trial 37 finished with value: 21.838300225842183 and parameters: {'n_estimators': 172, 'max_depth': 18, 'learning_rate': 0.7525222532905171, 'subsample': 0.8860510200608395, 'colsample_bytree': 0.9388725001730627, 'gamma': 3.0452370045841666, 'min_child_weight': 3, 'reg_alpha': 5.5117334676480574e-05, 'reg_lambda': 1.2142734350461057}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:20:40,108] Trial 38 finished with value: 29.634820351549592 and parameters: {'n_estimators': 189, 'max_depth': 19, 'learning_rate': 0.41271780290691773, 'subsample': 0.9716681132978057, 'colsample_bytree': 0.7607034959413529, 'gamma': 4.228906133811794, 'min_child_weight': 1, 'reg_alpha': 2.9548271314523405e-05, 'reg_lambda': 1.9841479015765626}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:20:46,960] Trial 39 finished with value: 15.763093175874198 and parameters: {'n_estimators': 143, 'max_depth': 20, 'learning_rate': 0.29424605058985187, 'subsample': 0.7938825272750005, 'colsample_bytree': 0.9856903752137349, 'gamma': 4.6286745272816265, 'min_child_weight': 3, 'reg_alpha': 0.00024177918052896473, 'reg_lambda': 0.3155402704440048}. Best is trial 29 with value: 14.3085909297159.
# [I 2024-11-29 12:20:49,283] A new study created in memory with name: no-name-b1e948fb-6c0c-436f-bcaf-f4f8bef43094
# Modelo salvo como: xgb_model_2022-08-30_to_2023-08-29.pkl
# Tunando hiperparâmetros para período de 2022-09-30 a 2023-09-29
# [I 2024-11-29 12:21:00,211] Trial 0 finished with value: 31.59114790902775 and parameters: {'n_estimators': 192, 'max_depth': 20, 'learning_rate': 0.3195678088389851, 'subsample': 0.6464378675319098, 'colsample_bytree': 0.6557641931435344, 'gamma': 2.041217415887196, 'min_child_weight': 4, 'reg_alpha': 0.00242096289708799, 'reg_lambda': 0.8021680681438014}. Best is trial 0 with value: 31.59114790902775.
# [I 2024-11-29 12:21:06,223] Trial 1 finished with value: 60.099846614121006 and parameters: {'n_estimators': 141, 'max_depth': 18, 'learning_rate': 0.7110962872657661, 'subsample': 0.5202260485952838, 'colsample_bytree': 0.5563596723021348, 'gamma': 2.796931632450046, 'min_child_weight': 10, 'reg_alpha': 0.00046177251330000184, 'reg_lambda': 0.004195673141025066}. Best is trial 0 with value: 31.59114790902775.
# [I 2024-11-29 12:21:08,034] Trial 2 finished with value: 32.35436895905624 and parameters: {'n_estimators': 130, 'max_depth': 4, 'learning_rate': 0.6823897256078283, 'subsample': 0.959303067401008, 'colsample_bytree': 0.9756219821469463, 'gamma': 4.58187265479898, 'min_child_weight': 9, 'reg_alpha': 8.97567413790125e-05, 'reg_lambda': 0.006080089798696315}. Best is trial 0 with value: 31.59114790902775.
# [I 2024-11-29 12:21:13,970] Trial 3 finished with value: 39.805878009281436 and parameters: {'n_estimators': 153, 'max_depth': 15, 'learning_rate': 0.4536394952194654, 'subsample': 0.7748799757702534, 'colsample_bytree': 0.6295252814538612, 'gamma': 2.1647500702281337, 'min_child_weight': 8, 'reg_alpha': 0.6041565491525662, 'reg_lambda': 0.0006455961446745702}. Best is trial 0 with value: 31.59114790902775.
# [I 2024-11-29 12:21:18,395] Trial 4 finished with value: 16.685767815173094 and parameters: {'n_estimators': 105, 'max_depth': 15, 'learning_rate': 0.08910313135341771, 'subsample': 0.5596047303215276, 'colsample_bytree': 0.8603161473532455, 'gamma': 2.69306209097623, 'min_child_weight': 3, 'reg_alpha': 0.04491079187364447, 'reg_lambda': 3.1935639198978825}. Best is trial 4 with value: 16.685767815173094.
# [I 2024-11-29 12:21:20,201] Trial 5 finished with value: 23.267474176257867 and parameters: {'n_estimators': 70, 'max_depth': 7, 'learning_rate': 0.7632257140767162, 'subsample': 0.9230319964039626, 'colsample_bytree': 0.9370231117767953, 'gamma': 1.6759953927005529, 'min_child_weight': 1, 'reg_alpha': 7.65730256565542, 'reg_lambda': 0.4099659112730472}. Best is trial 4 with value: 16.685767815173094.
# [I 2024-11-29 12:21:22,344] Trial 6 finished with value: 28.76797043802201 and parameters: {'n_estimators': 122, 'max_depth': 5, 'learning_rate': 0.26110526345446655, 'subsample': 0.8298398080189583, 'colsample_bytree': 0.7624369582562674, 'gamma': 2.3397293686156466, 'min_child_weight': 7, 'reg_alpha': 0.0020995160731452924, 'reg_lambda': 0.27992975453120617}. Best is trial 4 with value: 16.685767815173094.
# [I 2024-11-29 12:21:24,745] Trial 7 finished with value: 20.753013425843033 and parameters: {'n_estimators': 184, 'max_depth': 3, 'learning_rate': 0.7937570049941, 'subsample': 0.8262742174113898, 'colsample_bytree': 0.660392962555824, 'gamma': 1.2342326050630603, 'min_child_weight': 2, 'reg_alpha': 0.0070333727214812415, 'reg_lambda': 0.005387407838042883}. Best is trial 4 with value: 16.685767815173094.
# [I 2024-11-29 12:21:31,974] Trial 8 finished with value: 33.03080204734531 and parameters: {'n_estimators': 131, 'max_depth': 20, 'learning_rate': 0.3570145808477938, 'subsample': 0.8117094520377797, 'colsample_bytree': 0.7171724680550962, 'gamma': 0.5719574224099083, 'min_child_weight': 9, 'reg_alpha': 0.5069097862811387, 'reg_lambda': 0.14354050768354937}. Best is trial 4 with value: 16.685767815173094.
# [I 2024-11-29 12:21:42,134] Trial 9 finished with value: 26.906789371419062 and parameters: {'n_estimators': 174, 'max_depth': 17, 'learning_rate': 0.18498481493161503, 'subsample': 0.7662941916307031, 'colsample_bytree': 0.6805553240676703, 'gamma': 2.6246824571857403, 'min_child_weight': 3, 'reg_alpha': 0.26387545383942174, 'reg_lambda': 0.009817413365499645}. Best is trial 4 with value: 16.685767815173094.
# [I 2024-11-29 12:21:44,625] Trial 10 finished with value: 432.66803439845273 and parameters: {'n_estimators': 82, 'max_depth': 10, 'learning_rate': 0.014636052592738674, 'subsample': 0.5195775182513295, 'colsample_bytree': 0.8507610290216774, 'gamma': 3.8620925739808305, 'min_child_weight': 5, 'reg_alpha': 0.04041735471035232, 'reg_lambda': 5.543576576399097}. Best is trial 4 with value: 16.685767815173094.
# [I 2024-11-29 12:21:49,827] Trial 11 finished with value: 15.36717777440839 and parameters: {'n_estimators': 98, 'max_depth': 13, 'learning_rate': 0.5227254665060866, 'subsample': 0.665085090339835, 'colsample_bytree': 0.8102895374859311, 'gamma': 0.6303632761431808, 'min_child_weight': 1, 'reg_alpha': 0.023310689862779708, 'reg_lambda': 6.391005852721281e-05}. Best is trial 11 with value: 15.36717777440839.
# [I 2024-11-29 12:21:55,554] Trial 12 finished with value: 14.672088653623556 and parameters: {'n_estimators': 102, 'max_depth': 13, 'learning_rate': 0.5290279104354267, 'subsample': 0.6411382763210505, 'colsample_bytree': 0.8386872434546762, 'gamma': 0.0912054670338911, 'min_child_weight': 1, 'reg_alpha': 1.0073702647494443e-05, 'reg_lambda': 3.10561724945318e-05}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:21:58,619] Trial 13 finished with value: 15.429179354623951 and parameters: {'n_estimators': 50, 'max_depth': 12, 'learning_rate': 0.5399216236761977, 'subsample': 0.6693487351952004, 'colsample_bytree': 0.8140114357651402, 'gamma': 0.1715215608063856, 'min_child_weight': 1, 'reg_alpha': 2.3029910903738003e-05, 'reg_lambda': 1.0071307595140282e-05}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:01,627] Trial 14 finished with value: 23.578530200463252 and parameters: {'n_estimators': 100, 'max_depth': 11, 'learning_rate': 0.5746247482481713, 'subsample': 0.6633108792872173, 'colsample_bytree': 0.9067337894175305, 'gamma': 0.6375327557761641, 'min_child_weight': 6, 'reg_alpha': 0.0002855387453923322, 'reg_lambda': 1.2916480951233525e-05}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:06,736] Trial 15 finished with value: 15.027304101972287 and parameters: {'n_estimators': 98, 'max_depth': 13, 'learning_rate': 0.4780458719116938, 'subsample': 0.5971502953927852, 'colsample_bytree': 0.7767319788740759, 'gamma': 1.0766011692202393, 'min_child_weight': 1, 'reg_alpha': 2.3334528514378753e-05, 'reg_lambda': 0.00017552279341960587}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:08,955] Trial 16 finished with value: 18.395921488378338 and parameters: {'n_estimators': 80, 'max_depth': 9, 'learning_rate': 0.4389230670485906, 'subsample': 0.6007131055766655, 'colsample_bytree': 0.7622810004831476, 'gamma': 1.3070017658936544, 'min_child_weight': 3, 'reg_alpha': 1.3838705625168995e-05, 'reg_lambda': 0.00022628854958433675}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:13,672] Trial 17 finished with value: 45.70743032362108 and parameters: {'n_estimators': 111, 'max_depth': 14, 'learning_rate': 0.6328321927712877, 'subsample': 0.7115811407209063, 'colsample_bytree': 0.5870721259808792, 'gamma': 0.07511280199495506, 'min_child_weight': 5, 'reg_alpha': 9.036009280354676e-05, 'reg_lambda': 0.0005086135878881442}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:15,174] Trial 18 finished with value: 19.454619221322226 and parameters: {'n_estimators': 52, 'max_depth': 8, 'learning_rate': 0.4704491581689052, 'subsample': 0.6039816308973494, 'colsample_bytree': 0.8958574743620382, 'gamma': 1.1013782699771746, 'min_child_weight': 2, 'reg_alpha': 1.16335203188513e-05, 'reg_lambda': 5.703131525674302e-05}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:24,736] Trial 19 finished with value: 36.38165426125474 and parameters: {'n_estimators': 158, 'max_depth': 17, 'learning_rate': 0.36432993758425325, 'subsample': 0.5763543484327706, 'colsample_bytree': 0.7238780261763342, 'gamma': 3.468723546567621, 'min_child_weight': 2, 'reg_alpha': 8.281753785000447e-05, 'reg_lambda': 0.057828583935858276}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:28,005] Trial 20 finished with value: 56.102028947292105 and parameters: {'n_estimators': 85, 'max_depth': 12, 'learning_rate': 0.6164862893596939, 'subsample': 0.7131422769497007, 'colsample_bytree': 0.5168248335250021, 'gamma': 0.020727262513941164, 'min_child_weight': 4, 'reg_alpha': 0.0009165188510495282, 'reg_lambda': 7.867643839734377e-05}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:33,381] Trial 21 finished with value: 15.353508469268226 and parameters: {'n_estimators': 95, 'max_depth': 14, 'learning_rate': 0.548414426733165, 'subsample': 0.6331819940791423, 'colsample_bytree': 0.8096685828188588, 'gamma': 0.7136276024295725, 'min_child_weight': 1, 'reg_alpha': 0.021486436280970845, 'reg_lambda': 4.840873086025157e-05}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:39,503] Trial 22 finished with value: 15.623771763820665 and parameters: {'n_estimators': 118, 'max_depth': 14, 'learning_rate': 0.49957101501281836, 'subsample': 0.6349360498948542, 'colsample_bytree': 0.8077233742487995, 'gamma': 0.9137497456863147, 'min_child_weight': 1, 'reg_alpha': 4.266539655768265e-05, 'reg_lambda': 0.001357446478946913}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:44,145] Trial 23 finished with value: 15.984292715467891 and parameters: {'n_estimators': 92, 'max_depth': 15, 'learning_rate': 0.5929683893195392, 'subsample': 0.7259233837778323, 'colsample_bytree': 0.8555210523364902, 'gamma': 1.5155821795263842, 'min_child_weight': 2, 'reg_alpha': 0.11283456019003302, 'reg_lambda': 2.768327121562632e-05}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:47,078] Trial 24 finished with value: 15.001377991786535 and parameters: {'n_estimators': 66, 'max_depth': 11, 'learning_rate': 0.4183773559343929, 'subsample': 0.5539238457036576, 'colsample_bytree': 0.7871672596895903, 'gamma': 0.47314441814382613, 'min_child_weight': 1, 'reg_alpha': 0.006169083462818272, 'reg_lambda': 0.00023495231451821602}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:49,259] Trial 25 finished with value: 17.989980664661424 and parameters: {'n_estimators': 62, 'max_depth': 10, 'learning_rate': 0.2592475307360182, 'subsample': 0.550081916368407, 'colsample_bytree': 0.7740733126557782, 'gamma': 0.38946063435167144, 'min_child_weight': 4, 'reg_alpha': 0.0002716903900740072, 'reg_lambda': 0.00017728937126550027}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:50,958] Trial 26 finished with value: 38.76732838947254 and parameters: {'n_estimators': 69, 'max_depth': 7, 'learning_rate': 0.4035256465713649, 'subsample': 0.6001389485403741, 'colsample_bytree': 0.7157028200388225, 'gamma': 1.5933923317429017, 'min_child_weight': 3, 'reg_alpha': 0.0056867247341144825, 'reg_lambda': 0.0014670276105678568}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:53,897] Trial 27 finished with value: 16.004406389486412 and parameters: {'n_estimators': 73, 'max_depth': 11, 'learning_rate': 0.4160485169021874, 'subsample': 0.5108806416464048, 'colsample_bytree': 0.8958732264897067, 'gamma': 0.9638281451759884, 'min_child_weight': 2, 'reg_alpha': 3.2692951226276266e-05, 'reg_lambda': 0.00018269980950962457}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:22:59,333] Trial 28 finished with value: 15.182835146919384 and parameters: {'n_estimators': 112, 'max_depth': 13, 'learning_rate': 0.3320456009033449, 'subsample': 0.552798786510266, 'colsample_bytree': 0.9602900059117834, 'gamma': 0.29880992229665565, 'min_child_weight': 1, 'reg_alpha': 2.844981483537321, 'reg_lambda': 0.04389712871346369}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:23:01,179] Trial 29 finished with value: 31.24147320978252 and parameters: {'n_estimators': 62, 'max_depth': 9, 'learning_rate': 0.24662680296439923, 'subsample': 0.6884111761930901, 'colsample_bytree': 0.6940014865744583, 'gamma': 1.838898460489499, 'min_child_weight': 4, 'reg_alpha': 0.0021930287313262275, 'reg_lambda': 0.0004972700432041088}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:23:06,443] Trial 30 finished with value: 17.998433217530714 and parameters: {'n_estimators': 88, 'max_depth': 16, 'learning_rate': 0.6733322088021912, 'subsample': 0.6242613411555288, 'colsample_bytree': 0.7837480991890429, 'gamma': 0.9259181995458026, 'min_child_weight': 2, 'reg_alpha': 0.0001810955138312534, 'reg_lambda': 2.15707783960323e-05}. Best is trial 12 with value: 14.672088653623556.
# [I 2024-11-29 12:23:11,965] Trial 31 finished with value: 14.250466077692513 and parameters: {'n_estimators': 111, 'max_depth': 13, 'learning_rate': 0.3047913452087959, 'subsample': 0.5490864981798194, 'colsample_bytree': 0.9894500354743829, 'gamma': 0.32470507343846605, 'min_child_weight': 1, 'reg_alpha': 2.380770590405801, 'reg_lambda': 0.02314817787711741}. Best is trial 31 with value: 14.250466077692513.
# [I 2024-11-29 12:23:18,921] Trial 32 finished with value: 14.711341688438107 and parameters: {'n_estimators': 138, 'max_depth': 13, 'learning_rate': 0.292156762279724, 'subsample': 0.584176876690262, 'colsample_bytree': 0.9974933496112146, 'gamma': 0.3644289755745635, 'min_child_weight': 1, 'reg_alpha': 1.686803051596362, 'reg_lambda': 0.021491428388507282}. Best is trial 31 with value: 14.250466077692513.
# [I 2024-11-29 12:23:23,829] Trial 33 finished with value: 14.085768482343699 and parameters: {'n_estimators': 141, 'max_depth': 12, 'learning_rate': 0.18734048589346738, 'subsample': 0.5010400191905517, 'colsample_bytree': 0.9412782343376314, 'gamma': 0.355751503345529, 'min_child_weight': 2, 'reg_alpha': 2.1782619840687802, 'reg_lambda': 0.03044086961144119}. Best is trial 33 with value: 14.085768482343699.
# [I 2024-11-29 12:23:28,844] Trial 34 finished with value: 14.074412011655705 and parameters: {'n_estimators': 145, 'max_depth': 12, 'learning_rate': 0.1784033314301617, 'subsample': 0.5010547933889404, 'colsample_bytree': 0.9915701711309027, 'gamma': 0.05884420249555744, 'min_child_weight': 2, 'reg_alpha': 1.8996324834226448, 'reg_lambda': 0.02583211205927781}. Best is trial 34 with value: 14.074412011655705.
# [I 2024-11-29 12:23:33,804] Trial 35 finished with value: 14.428699719955414 and parameters: {'n_estimators': 151, 'max_depth': 12, 'learning_rate': 0.1644358806689882, 'subsample': 0.5001278483339217, 'colsample_bytree': 0.9355682919934004, 'gamma': 0.20972228802458462, 'min_child_weight': 3, 'reg_alpha': 6.359004875547093, 'reg_lambda': 0.018170847606681192}. Best is trial 34 with value: 14.074412011655705.
# [I 2024-11-29 12:23:38,055] Trial 36 finished with value: 14.602293784233273 and parameters: {'n_estimators': 154, 'max_depth': 10, 'learning_rate': 0.15999631589346475, 'subsample': 0.5104031444988718, 'colsample_bytree': 0.9383833589461634, 'gamma': 3.3940300164343284, 'min_child_weight': 3, 'reg_alpha': 5.135894106386308, 'reg_lambda': 0.020144608989390717}. Best is trial 34 with value: 14.074412011655705.
# [I 2024-11-29 12:23:42,577] Trial 37 finished with value: 16.942137167785923 and parameters: {'n_estimators': 145, 'max_depth': 12, 'learning_rate': 0.16154409592632968, 'subsample': 0.5343924431938444, 'colsample_bytree': 0.9814998418090521, 'gamma': 0.7676115237243007, 'min_child_weight': 4, 'reg_alpha': 1.2422433817486602, 'reg_lambda': 1.0838805391169986}. Best is trial 34 with value: 14.074412011655705.
# [I 2024-11-29 12:23:49,245] Trial 38 finished with value: 13.315245714063256 and parameters: {'n_estimators': 164, 'max_depth': 15, 'learning_rate': 0.09970494749069976, 'subsample': 0.5029046029497692, 'colsample_bytree': 0.947614532448335, 'gamma': 1.3528287249658533, 'min_child_weight': 3, 'reg_alpha': 7.49226323949596, 'reg_lambda': 0.0027766851680881216}. Best is trial 38 with value: 13.315245714063256.
# [I 2024-11-29 12:24:00,104] Trial 39 finished with value: 13.974816466615305 and parameters: {'n_estimators': 166, 'max_depth': 19, 'learning_rate': 0.10608094958488508, 'subsample': 0.8852888926945202, 'colsample_bytree': 0.9591037834778386, 'gamma': 2.007382340797911, 'min_child_weight': 2, 'reg_alpha': 0.8821647729246781, 'reg_lambda': 0.0020656431174590315}. Best is trial 38 with value: 13.315245714063256.
# [I 2024-11-29 12:24:01,469] A new study created in memory with name: no-name-7764bd39-8d76-44bd-8e86-a19074b11f85
# Modelo salvo como: xgb_model_2022-09-30_to_2023-09-29.pkl
# Tunando hiperparâmetros para período de 2022-10-30 a 2023-10-29
# [I 2024-11-29 12:24:07,648] Trial 0 finished with value: 17.935300802521965 and parameters: {'n_estimators': 147, 'max_depth': 14, 'learning_rate': 0.23079849728264779, 'subsample': 0.8748912192116471, 'colsample_bytree': 0.8312028709464663, 'gamma': 3.614614349360675, 'min_child_weight': 5, 'reg_alpha': 3.473762433533894e-05, 'reg_lambda': 0.005563174088357416}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:10,947] Trial 1 finished with value: 35.70100232405937 and parameters: {'n_estimators': 68, 'max_depth': 16, 'learning_rate': 0.5026215187717633, 'subsample': 0.9919883987441154, 'colsample_bytree': 0.7556277164461827, 'gamma': 1.8561961207684745, 'min_child_weight': 8, 'reg_alpha': 0.04690273740040255, 'reg_lambda': 0.003400089785687547}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:16,501] Trial 2 finished with value: 36.441604378641685 and parameters: {'n_estimators': 116, 'max_depth': 16, 'learning_rate': 0.2755011864495492, 'subsample': 0.8420917294121006, 'colsample_bytree': 0.5974486636536915, 'gamma': 3.8851911794674114, 'min_child_weight': 5, 'reg_alpha': 1.3094437800158183, 'reg_lambda': 0.03005056284860578}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:22,995] Trial 3 finished with value: 34.9621962902353 and parameters: {'n_estimators': 140, 'max_depth': 15, 'learning_rate': 0.17955863090075894, 'subsample': 0.514616297027179, 'colsample_bytree': 0.6105512577417067, 'gamma': 1.4115881368674466, 'min_child_weight': 3, 'reg_alpha': 1.618567519330436e-05, 'reg_lambda': 0.009170237660256614}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:31,811] Trial 4 finished with value: 59.15459533517166 and parameters: {'n_estimators': 153, 'max_depth': 15, 'learning_rate': 0.31228708954385737, 'subsample': 0.7776919741291558, 'colsample_bytree': 0.5023041716834213, 'gamma': 4.78713115413292, 'min_child_weight': 2, 'reg_alpha': 2.3868087869970447, 'reg_lambda': 0.01363566103175112}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:33,772] Trial 5 finished with value: 27.984371945356145 and parameters: {'n_estimators': 140, 'max_depth': 4, 'learning_rate': 0.3848809495292981, 'subsample': 0.9271885284218347, 'colsample_bytree': 0.7138679812898101, 'gamma': 3.3323090576169005, 'min_child_weight': 1, 'reg_alpha': 2.090860697874494, 'reg_lambda': 0.011594287046929021}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:39,243] Trial 6 finished with value: 31.83095523882157 and parameters: {'n_estimators': 185, 'max_depth': 11, 'learning_rate': 0.7017278763755084, 'subsample': 0.6362398924280166, 'colsample_bytree': 0.7996717884131941, 'gamma': 2.7697294721052894, 'min_child_weight': 10, 'reg_alpha': 0.00013766759848296144, 'reg_lambda': 0.07161333631490725}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:41,924] Trial 7 finished with value: 23.174395489672357 and parameters: {'n_estimators': 93, 'max_depth': 9, 'learning_rate': 0.5520819885584509, 'subsample': 0.9079605911213509, 'colsample_bytree': 0.8622908259742741, 'gamma': 4.722676601557382, 'min_child_weight': 5, 'reg_alpha': 2.110420718167375, 'reg_lambda': 0.006195329289410976}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:45,517] Trial 8 finished with value: 43.34002708923744 and parameters: {'n_estimators': 79, 'max_depth': 15, 'learning_rate': 0.7170842913369476, 'subsample': 0.6568930879071189, 'colsample_bytree': 0.6615687276947584, 'gamma': 0.9755763959951735, 'min_child_weight': 7, 'reg_alpha': 0.02453495951744699, 'reg_lambda': 3.441787789826079e-05}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:24:49,970] Trial 9 finished with value: 19.163183700131178 and parameters: {'n_estimators': 158, 'max_depth': 10, 'learning_rate': 0.26812649308497916, 'subsample': 0.9358694902626932, 'colsample_bytree': 0.9818411490035176, 'gamma': 4.967462045273549, 'min_child_weight': 9, 'reg_alpha': 4.655492058324934, 'reg_lambda': 0.00018599087977014728}. Best is trial 0 with value: 17.935300802521965.
# [I 2024-11-29 12:25:01,035] Trial 10 finished with value: 15.787209736875505 and parameters: {'n_estimators': 196, 'max_depth': 20, 'learning_rate': 0.045189175928546516, 'subsample': 0.7486568535472988, 'colsample_bytree': 0.9196724417777968, 'gamma': 0.21939181257724538, 'min_child_weight': 4, 'reg_alpha': 0.001075071628162428, 'reg_lambda': 5.181227786884482}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:25:11,587] Trial 11 finished with value: 16.22042209478268 and parameters: {'n_estimators': 200, 'max_depth': 20, 'learning_rate': 0.051742334716043836, 'subsample': 0.7489182677648265, 'colsample_bytree': 0.9317406767282577, 'gamma': 0.512693854465561, 'min_child_weight': 4, 'reg_alpha': 0.0004911473811300087, 'reg_lambda': 9.87352747220691}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:25:18,315] Trial 12 finished with value: 123.18225436987159 and parameters: {'n_estimators': 199, 'max_depth': 20, 'learning_rate': 0.01287888012651063, 'subsample': 0.7108527633646743, 'colsample_bytree': 0.9749579913568868, 'gamma': 0.0887978295437919, 'min_child_weight': 3, 'reg_alpha': 0.0007813931094900808, 'reg_lambda': 8.224865734887043}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:25:28,323] Trial 13 finished with value: 16.776351450546493 and parameters: {'n_estimators': 173, 'max_depth': 20, 'learning_rate': 0.052660789249828754, 'subsample': 0.7774592187008288, 'colsample_bytree': 0.9005426843727088, 'gamma': 0.06220683791453124, 'min_child_weight': 4, 'reg_alpha': 0.0014987716712804074, 'reg_lambda': 7.804360207719145}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:25:36,815] Trial 14 finished with value: 18.102410405268913 and parameters: {'n_estimators': 199, 'max_depth': 18, 'learning_rate': 0.13305431772304704, 'subsample': 0.7031355431115193, 'colsample_bytree': 0.9264921830593895, 'gamma': 0.704091281139313, 'min_child_weight': 7, 'reg_alpha': 0.002763422029162381, 'reg_lambda': 0.7140209049681817}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:25:40,400] Trial 15 finished with value: 17.564135735802175 and parameters: {'n_estimators': 177, 'max_depth': 7, 'learning_rate': 0.08131621602462019, 'subsample': 0.5826207251059137, 'colsample_bytree': 0.9208867221287661, 'gamma': 1.9212893348105242, 'min_child_weight': 3, 'reg_alpha': 0.0003089556877613924, 'reg_lambda': 0.8483428027948238}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:25:46,092] Trial 16 finished with value: 16.669532070524575 and parameters: {'n_estimators': 117, 'max_depth': 18, 'learning_rate': 0.12411456428693406, 'subsample': 0.8293756241690613, 'colsample_bytree': 0.9983342228265555, 'gamma': 0.6832757255313049, 'min_child_weight': 6, 'reg_alpha': 0.008181160845685063, 'reg_lambda': 0.7031484402669965}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:25:54,613] Trial 17 finished with value: 18.037952320330138 and parameters: {'n_estimators': 172, 'max_depth': 18, 'learning_rate': 0.405208306557049, 'subsample': 0.7368716610449015, 'colsample_bytree': 0.8577783261044305, 'gamma': 1.3917515864557468, 'min_child_weight': 1, 'reg_alpha': 0.19426259355218448, 'reg_lambda': 2.018269347494282}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:26:01,019] Trial 18 finished with value: 16.65819207837158 and parameters: {'n_estimators': 188, 'max_depth': 13, 'learning_rate': 0.17842883696568887, 'subsample': 0.656784868057427, 'colsample_bytree': 0.773182577957433, 'gamma': 2.3823509068733153, 'min_child_weight': 4, 'reg_alpha': 0.00012552805166143855, 'reg_lambda': 0.15973496723119351}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:26:07,186] Trial 19 finished with value: 88.99464584781882 and parameters: {'n_estimators': 163, 'max_depth': 20, 'learning_rate': 0.01746721478685863, 'subsample': 0.7981557058618454, 'colsample_bytree': 0.9413330644925002, 'gamma': 0.5013595889425708, 'min_child_weight': 6, 'reg_alpha': 0.0031549549565586203, 'reg_lambda': 2.5577861817797882}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:26:12,255] Trial 20 finished with value: 30.68814431815507 and parameters: {'n_estimators': 101, 'max_depth': 18, 'learning_rate': 0.7976720465635782, 'subsample': 0.6095598355046807, 'colsample_bytree': 0.8834876387125765, 'gamma': 1.2771107778286934, 'min_child_weight': 4, 'reg_alpha': 0.0004919810934105406, 'reg_lambda': 0.18890660594080375}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:26:18,610] Trial 21 finished with value: 17.4929046123692 and parameters: {'n_estimators': 188, 'max_depth': 13, 'learning_rate': 0.18948171032344574, 'subsample': 0.6828324669550804, 'colsample_bytree': 0.788024995115106, 'gamma': 2.410273530898608, 'min_child_weight': 4, 'reg_alpha': 5.300248988097253e-05, 'reg_lambda': 0.20522921038675748}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:26:20,890] Trial 22 finished with value: 39.282399513670875 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.11964101530695814, 'subsample': 0.5355203957747777, 'colsample_bytree': 0.7105205582287909, 'gamma': 2.8271783937710784, 'min_child_weight': 2, 'reg_alpha': 0.00014195334206961187, 'reg_lambda': 2.914370097359342}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:26:24,639] Trial 23 finished with value: 20.3976608785428 and parameters: {'n_estimators': 186, 'max_depth': 6, 'learning_rate': 0.08645642361763922, 'subsample': 0.751739892212449, 'colsample_bytree': 0.8349745883673694, 'gamma': 2.137039497982377, 'min_child_weight': 4, 'reg_alpha': 1.021828203351554e-05, 'reg_lambda': 0.0006661868263397034}. Best is trial 10 with value: 15.787209736875505.
# [I 2024-11-29 12:26:27,335] Trial 24 finished with value: 14.150656755133639 and parameters: {'n_estimators': 54, 'max_depth': 12, 'learning_rate': 0.16844595764667863, 'subsample': 0.6620914692373807, 'colsample_bytree': 0.9453385109608448, 'gamma': 0.32952841517598425, 'min_child_weight': 2, 'reg_alpha': 0.000114359308595139, 'reg_lambda': 0.18930296026493823}. Best is trial 24 with value: 14.150656755133639.
# [I 2024-11-29 12:26:29,805] Trial 25 finished with value: 43.42202812537047 and parameters: {'n_estimators': 61, 'max_depth': 17, 'learning_rate': 0.06097143604907569, 'subsample': 0.583268059995463, 'colsample_bytree': 0.9554832741865188, 'gamma': 0.21262498833462076, 'min_child_weight': 2, 'reg_alpha': 0.007323885878546857, 'reg_lambda': 5.5681596070152946}. Best is trial 24 with value: 14.150656755133639.
# [I 2024-11-29 12:26:32,874] Trial 26 finished with value: 20.276654982427026 and parameters: {'n_estimators': 127, 'max_depth': 8, 'learning_rate': 0.34576510327758914, 'subsample': 0.7319702835219041, 'colsample_bytree': 0.8922785851701504, 'gamma': 0.9678602120857369, 'min_child_weight': 3, 'reg_alpha': 0.0014059226780145269, 'reg_lambda': 1.1640587844310148}. Best is trial 24 with value: 14.150656755133639.
# [I 2024-11-29 12:26:36,445] Trial 27 finished with value: 15.37705470350428 and parameters: {'n_estimators': 88, 'max_depth': 12, 'learning_rate': 0.2115190002344183, 'subsample': 0.8172050795490526, 'colsample_bytree': 0.9494118353962626, 'gamma': 0.3466725284736616, 'min_child_weight': 2, 'reg_alpha': 4.8683010997984324e-05, 'reg_lambda': 0.3428554919418569}. Best is trial 24 with value: 14.150656755133639.
# [I 2024-11-29 12:26:39,855] Trial 28 finished with value: 14.412722391906021 and parameters: {'n_estimators': 50, 'max_depth': 12, 'learning_rate': 0.22058047549102638, 'subsample': 0.7918878423482875, 'colsample_bytree': 0.9654771356512238, 'gamma': 0.9765081899735104, 'min_child_weight': 1, 'reg_alpha': 3.8740724309649454e-05, 'reg_lambda': 0.05587663675995273}. Best is trial 24 with value: 14.150656755133639.
# [I 2024-11-29 12:26:43,433] Trial 29 finished with value: 14.56405602908498 and parameters: {'n_estimators': 50, 'max_depth': 12, 'learning_rate': 0.23006529987611496, 'subsample': 0.8637699867742908, 'colsample_bytree': 0.8221401682780418, 'gamma': 0.9921128816689293, 'min_child_weight': 1, 'reg_alpha': 3.437083376753751e-05, 'reg_lambda': 0.05101165075991532}. Best is trial 24 with value: 14.150656755133639.
# [I 2024-11-29 12:26:45,981] Trial 30 finished with value: 16.070485523030626 and parameters: {'n_estimators': 52, 'max_depth': 11, 'learning_rate': 0.46814613354568196, 'subsample': 0.8409197559050903, 'colsample_bytree': 0.8159835438411295, 'gamma': 1.6241752008312105, 'min_child_weight': 1, 'reg_alpha': 2.4263221069255253e-05, 'reg_lambda': 0.0644508927447951}. Best is trial 24 with value: 14.150656755133639.
# [I 2024-11-29 12:26:49,518] Trial 31 finished with value: 15.23920838732696 and parameters: {'n_estimators': 74, 'max_depth': 13, 'learning_rate': 0.22343077749578946, 'subsample': 0.878400668071792, 'colsample_bytree': 0.965238575450494, 'gamma': 0.953328119609238, 'min_child_weight': 2, 'reg_alpha': 4.677926954808016e-05, 'reg_lambda': 0.33453290835164057}. Best is trial 24 with value: 14.150656755133639.
# [I 2024-11-29 12:26:53,541] Trial 32 finished with value: 15.102542320183181 and parameters: {'n_estimators': 50, 'max_depth': 13, 'learning_rate': 0.27697825072890064, 'subsample': 0.8794979266588728, 'colsample_bytree': 0.9772764907500051, 'gamma': 1.011418590969973, 'min_child_weight': 1, 'reg_alpha': 4.9965070682094136e-05, 'reg_lambda': 0.04250981679269697}. Best is trial 24 with value: 14.150656755133639.
# ...
# [I 2024-11-29 13:12:30,173] Trial 2 finished with value: 64.41173195141685 and parameters: {'n_estimators': 60, 'max_depth': 18, 'learning_rate': 0.6585880110119566, 'subsample': 0.7175202048088296, 'colsample_bytree': 0.5511246993146165, 'gamma': 0.5772888630745621, 'min_child_weight': 7, 'reg_alpha': 0.0002714532445495636, 'reg_lambda': 0.05145745151557915}. Best is trial 1 with value: 32.49660911948679.
# [I 2024-11-29 13:12:36,361] Trial 3 finished with value: 35.051763174774756 and parameters: {'n_estimators': 59, 'max_depth': 16, 'learning_rate': 0.3681854687686541, 'subsample': 0.6595020513912514, 'colsample_bytree': 0.7023388930337793, 'gamma': 1.8120571885315044, 'min_child_weight': 1, 'reg_alpha': 1.3321426797575932e-05, 'reg_lambda': 2.3120778074451384e-05}. Best is trial 1 with value: 32.49660911948679.
# [I 2024-11-29 13:12:40,854] Trial 4 finished with value: 53.8926329695268 and parameters: {'n_estimators': 135, 'max_depth': 13, 'learning_rate': 0.7662326027064995, 'subsample': 0.6856379848076639, 'colsample_bytree': 0.5656925722695767, 'gamma': 4.645066233960497, 'min_child_weight': 6, 'reg_alpha': 1.2648223306337698e-05, 'reg_lambda': 1.5191706459566108e-05}. Best is trial 1 with value: 32.49660911948679.
# [I 2024-11-29 13:12:44,838] Trial 5 finished with value: 47.7256730496823 and parameters: {'n_estimators': 104, 'max_depth': 15, 'learning_rate': 0.7694295303657658, 'subsample': 0.9945287168537104, 'colsample_bytree': 0.6121899019842172, 'gamma': 3.0586607396568093, 'min_child_weight': 10, 'reg_alpha': 3.346466222864552, 'reg_lambda': 0.013143550450524635}. Best is trial 1 with value: 32.49660911948679.
# [I 2024-11-29 13:12:46,186] Trial 6 finished with value: 36.85545206893639 and parameters: {'n_estimators': 104, 'max_depth': 3, 'learning_rate': 0.7728318396636584, 'subsample': 0.8193119822350249, 'colsample_bytree': 0.5158061530207176, 'gamma': 1.349229843081206, 'min_child_weight': 3, 'reg_alpha': 0.03162344936052263, 'reg_lambda': 2.907935867574885}. Best is trial 1 with value: 32.49660911948679.
# [I 2024-11-29 13:12:53,165] Trial 7 finished with value: 23.918698171983774 and parameters: {'n_estimators': 168, 'max_depth': 18, 'learning_rate': 0.3447337737026854, 'subsample': 0.7266017224623053, 'colsample_bytree': 0.8839127831845489, 'gamma': 4.069110852697339, 'min_child_weight': 8, 'reg_alpha': 0.16966187369135105, 'reg_lambda': 4.066343031167565e-05}. Best is trial 7 with value: 23.918698171983774.
# [I 2024-11-29 13:12:57,999] Trial 8 finished with value: 37.411049706756245 and parameters: {'n_estimators': 180, 'max_depth': 11, 'learning_rate': 0.7319628145672197, 'subsample': 0.6925830723194077, 'colsample_bytree': 0.9742017855489387, 'gamma': 0.39944406816925904, 'min_child_weight': 10, 'reg_alpha': 0.05713376465897339, 'reg_lambda': 0.004133426248595221}. Best is trial 7 with value: 23.918698171983774.
# [I 2024-11-29 13:13:05,828] Trial 9 finished with value: 30.161033339271903 and parameters: {'n_estimators': 183, 'max_depth': 15, 'learning_rate': 0.29664104603362124, 'subsample': 0.988536813587074, 'colsample_bytree': 0.6345269990574308, 'gamma': 3.066484751173839, 'min_child_weight': 4, 'reg_alpha': 0.0019936942491010426, 'reg_lambda': 0.005115323460838575}. Best is trial 7 with value: 23.918698171983774.
# [I 2024-11-29 13:13:15,991] Trial 10 finished with value: 19.793448916438784 and parameters: {'n_estimators': 200, 'max_depth': 20, 'learning_rate': 0.07225909786330531, 'subsample': 0.835429652934066, 'colsample_bytree': 0.8255164643811547, 'gamma': 4.009483635120884, 'min_child_weight': 8, 'reg_alpha': 3.070114173353591, 'reg_lambda': 8.652104559602849e-05}. Best is trial 10 with value: 19.793448916438784.
# [I 2024-11-29 13:13:26,686] Trial 11 finished with value: 20.808500856953664 and parameters: {'n_estimators': 198, 'max_depth': 20, 'learning_rate': 0.04184011829061762, 'subsample': 0.8512754140286892, 'colsample_bytree': 0.8322174002950739, 'gamma': 4.163819769048112, 'min_child_weight': 8, 'reg_alpha': 7.806659425727784, 'reg_lambda': 0.00025249566725220286}. Best is trial 10 with value: 19.793448916438784.
# [I 2024-11-29 13:13:38,866] Trial 12 finished with value: 27.48500940970581 and parameters: {'n_estimators': 199, 'max_depth': 20, 'learning_rate': 0.023793889328311252, 'subsample': 0.8619566527016476, 'colsample_bytree': 0.7983383397915332, 'gamma': 4.958780474653373, 'min_child_weight': 8, 'reg_alpha': 5.305434663455909, 'reg_lambda': 0.00020972316339918457}. Best is trial 10 with value: 19.793448916438784.
# [I 2024-11-29 13:13:45,392] Trial 13 finished with value: 63.842050732761756 and parameters: {'n_estimators': 157, 'max_depth': 10, 'learning_rate': 0.02015713236985775, 'subsample': 0.8758166381636179, 'colsample_bytree': 0.7884847087112756, 'gamma': 3.7268663396186685, 'min_child_weight': 8, 'reg_alpha': 9.854239567958839, 'reg_lambda': 0.0002912056984703164}. Best is trial 10 with value: 19.793448916438784.
# [I 2024-11-29 13:13:54,105] Trial 14 finished with value: 20.182972293753885 and parameters: {'n_estimators': 194, 'max_depth': 20, 'learning_rate': 0.17247862950187615, 'subsample': 0.8181919763401487, 'colsample_bytree': 0.8681377172459965, 'gamma': 2.2351800750542816, 'min_child_weight': 9, 'reg_alpha': 0.6701238731886175, 'reg_lambda': 0.00019773765457586537}. Best is trial 10 with value: 19.793448916438784.
# [I 2024-11-29 13:13:57,082] Trial 15 finished with value: 33.92705757442309 and parameters: {'n_estimators': 132, 'max_depth': 8, 'learning_rate': 0.18162444690584553, 'subsample': 0.9183278535435871, 'colsample_bytree': 0.7108240659266072, 'gamma': 1.7743403650037821, 'min_child_weight': 10, 'reg_alpha': 0.7359752099866748, 'reg_lambda': 0.35350680153217023}. Best is trial 10 with value: 19.793448916438784.
# [I 2024-11-29 13:14:03,268] Trial 16 finished with value: 17.204007437219648 and parameters: {'n_estimators': 180, 'max_depth': 13, 'learning_rate': 0.15775469424683475, 'subsample': 0.7923067686031176, 'colsample_bytree': 0.9900142074446117, 'gamma': 2.3528231042232117, 'min_child_weight': 6, 'reg_alpha': 0.8584946652210818, 'reg_lambda': 0.0004971128588293849}. Best is trial 16 with value: 17.204007437219648.
# [I 2024-11-29 13:14:08,403] Trial 17 finished with value: 26.81248082233059 and parameters: {'n_estimators': 168, 'max_depth': 13, 'learning_rate': 0.4694648367515403, 'subsample': 0.6106914712146334, 'colsample_bytree': 0.9751885047213519, 'gamma': 2.7034544121622193, 'min_child_weight': 6, 'reg_alpha': 0.0030131155123421394, 'reg_lambda': 0.03935044177774348}. Best is trial 16 with value: 17.204007437219648.
# [I 2024-11-29 13:14:11,721] Trial 18 finished with value: 17.748557263632673 and parameters: {'n_estimators': 147, 'max_depth': 8, 'learning_rate': 0.1561441157788729, 'subsample': 0.7808491121358215, 'colsample_bytree': 0.9188034299882653, 'gamma': 3.5917612666838066, 'min_child_weight': 5, 'reg_alpha': 1.782408991007922, 'reg_lambda': 6.753653713585951e-05}. Best is trial 16 with value: 17.204007437219648.
# [I 2024-11-29 13:14:14,124] Trial 19 finished with value: 21.26850745055135 and parameters: {'n_estimators': 115, 'max_depth': 7, 'learning_rate': 0.23717817794884363, 'subsample': 0.7675456499419062, 'colsample_bytree': 0.9322878905491304, 'gamma': 3.4490741024410565, 'min_child_weight': 5, 'reg_alpha': 0.1745777902057344, 'reg_lambda': 0.0008913309845442657}. Best is trial 16 with value: 17.204007437219648.
# [I 2024-11-29 13:14:18,998] Trial 20 finished with value: 13.044618854706911 and parameters: {'n_estimators': 153, 'max_depth': 9, 'learning_rate': 0.13242016855187674, 'subsample': 0.7768712947379722, 'colsample_bytree': 0.9861808111909235, 'gamma': 2.2988780583473076, 'min_child_weight': 1, 'reg_alpha': 1.0647662485234857, 'reg_lambda': 0.0008902792185811108}. Best is trial 20 with value: 13.044618854706911.
# [I 2024-11-29 13:14:23,599] Trial 21 finished with value: 12.993281166378292 and parameters: {'n_estimators': 147, 'max_depth': 9, 'learning_rate': 0.12584356806808128, 'subsample': 0.7712088289093573, 'colsample_bytree': 0.9929973085242894, 'gamma': 2.297036163528833, 'min_child_weight': 1, 'reg_alpha': 1.3605692717670652, 'reg_lambda': 1.0051768024533088e-05}. Best is trial 21 with value: 12.993281166378292.
# [I 2024-11-29 13:14:30,032] Trial 22 finished with value: 13.093187423855412 and parameters: {'n_estimators': 168, 'max_depth': 10, 'learning_rate': 0.11552435444068382, 'subsample': 0.7813422507632162, 'colsample_bytree': 0.9896211544238235, 'gamma': 2.154664004466804, 'min_child_weight': 1, 'reg_alpha': 1.1037732420142417, 'reg_lambda': 1.1390624542029832e-05}. Best is trial 21 with value: 12.993281166378292.
# [I 2024-11-29 13:14:35,077] Trial 23 finished with value: 17.756337204587307 and parameters: {'n_estimators': 162, 'max_depth': 10, 'learning_rate': 0.49566978364491154, 'subsample': 0.6099752026716729, 'colsample_bytree': 0.9461263201141473, 'gamma': 1.050370471376464, 'min_child_weight': 1, 'reg_alpha': 0.14447817751564102, 'reg_lambda': 1.0790312774068855e-05}. Best is trial 21 with value: 12.993281166378292.
# [I 2024-11-29 13:14:37,314] Trial 24 finished with value: 19.34284079319621 and parameters: {'n_estimators': 141, 'max_depth': 5, 'learning_rate': 0.10078994183645061, 'subsample': 0.9101759706941768, 'colsample_bytree': 0.9827604803056985, 'gamma': 1.8450390952433209, 'min_child_weight': 2, 'reg_alpha': 0.008187667296647591, 'reg_lambda': 6.478362497580602e-05}. Best is trial 21 with value: 12.993281166378292.
# [I 2024-11-29 13:14:40,591] Trial 25 finished with value: 14.440208147898877 and parameters: {'n_estimators': 122, 'max_depth': 9, 'learning_rate': 0.25207780867402213, 'subsample': 0.7533192101973202, 'colsample_bytree': 0.9494367916421044, 'gamma': 1.3909052606940875, 'min_child_weight': 2, 'reg_alpha': 1.5345364963470711, 'reg_lambda': 2.5926925033985177e-05}. Best is trial 21 with value: 12.993281166378292.
# [I 2024-11-29 13:14:46,454] Trial 26 finished with value: 12.495726689936896 and parameters: {'n_estimators': 157, 'max_depth': 11, 'learning_rate': 0.11748976338052108, 'subsample': 0.6334983828247713, 'colsample_bytree': 0.9964101488653031, 'gamma': 2.131000745981264, 'min_child_weight': 2, 'reg_alpha': 0.2628883917515764, 'reg_lambda': 1.087691644557979e-05}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:14:51,640] Trial 27 finished with value: 14.777866912839297 and parameters: {'n_estimators': 152, 'max_depth': 12, 'learning_rate': 0.22937494899908556, 'subsample': 0.63055709690693, 'colsample_bytree': 0.8688337821486083, 'gamma': 2.5764179009640245, 'min_child_weight': 2, 'reg_alpha': 0.19997891466275927, 'reg_lambda': 0.17532381763085053}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:14:53,593] Trial 28 finished with value: 32.667218673476185 and parameters: {'n_estimators': 126, 'max_depth': 5, 'learning_rate': 0.43848759339049437, 'subsample': 0.5507268626943919, 'colsample_bytree': 0.9179812556502213, 'gamma': 1.1790577891038598, 'min_child_weight': 3, 'reg_alpha': 0.06781144772659592, 'reg_lambda': 8.905946868260369}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:14:56,293] Trial 29 finished with value: 17.563662373480348 and parameters: {'n_estimators': 144, 'max_depth': 6, 'learning_rate': 0.10760516513477142, 'subsample': 0.727319590307151, 'colsample_bytree': 0.9435959378088036, 'gamma': 0.8537769934446637, 'min_child_weight': 2, 'reg_alpha': 0.2974880304949002, 'reg_lambda': 0.0010891525583518523}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:01,071] Trial 30 finished with value: 17.32160101505381 and parameters: {'n_estimators': 160, 'max_depth': 11, 'learning_rate': 0.29377004900247783, 'subsample': 0.588831646194924, 'colsample_bytree': 0.851795640365354, 'gamma': 1.9980810013575458, 'min_child_weight': 4, 'reg_alpha': 0.014879890460101844, 'reg_lambda': 9.910946121278234e-05}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:06,638] Trial 31 finished with value: 12.590555726803625 and parameters: {'n_estimators': 176, 'max_depth': 9, 'learning_rate': 0.11107993693234754, 'subsample': 0.7906439714395261, 'colsample_bytree': 0.9951457622262032, 'gamma': 2.172429241651746, 'min_child_weight': 1, 'reg_alpha': 0.6370935460505217, 'reg_lambda': 1.0158622441696843e-05}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:10,782] Trial 32 finished with value: 20.024091135728817 and parameters: {'n_estimators': 175, 'max_depth': 8, 'learning_rate': 0.5498127887511185, 'subsample': 0.6635101606482513, 'colsample_bytree': 0.9030292505494605, 'gamma': 2.702858551212472, 'min_child_weight': 1, 'reg_alpha': 0.5221299471901192, 'reg_lambda': 2.901916977934557e-05}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:15,055] Trial 33 finished with value: 13.620148107226665 and parameters: {'n_estimators': 151, 'max_depth': 9, 'learning_rate': 0.08429052186429489, 'subsample': 0.7411853404327862, 'colsample_bytree': 0.9994802899385138, 'gamma': 1.5297490861191616, 'min_child_weight': 2, 'reg_alpha': 2.887553828343386, 'reg_lambda': 1.1388816106336373e-05}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:21,815] Trial 34 finished with value: 13.177930210422925 and parameters: {'n_estimators': 187, 'max_depth': 12, 'learning_rate': 0.21069347780446646, 'subsample': 0.8034640936433075, 'colsample_bytree': 0.965079876874344, 'gamma': 2.364935179583074, 'min_child_weight': 1, 'reg_alpha': 0.07106922086395644, 'reg_lambda': 3.6777752025386425e-05}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:24,559] Trial 35 finished with value: 17.753175929549393 and parameters: {'n_estimators': 135, 'max_depth': 7, 'learning_rate': 0.13204063201607016, 'subsample': 0.7052588781683821, 'colsample_bytree': 0.909843874330544, 'gamma': 2.871835694780506, 'min_child_weight': 3, 'reg_alpha': 0.39701485401518427, 'reg_lambda': 0.00013342021343640457}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:26,977] Trial 36 finished with value: 15.822665912160181 and parameters: {'n_estimators': 78, 'max_depth': 9, 'learning_rate': 0.3131863662794685, 'subsample': 0.5277150814202484, 'colsample_bytree': 0.9502884381968917, 'gamma': 3.283639722892809, 'min_child_weight': 1, 'reg_alpha': 1.7930203495941863, 'reg_lambda': 0.0022904347737253547}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:30,165] Trial 37 finished with value: 18.481269706127577 and parameters: {'n_estimators': 173, 'max_depth': 6, 'learning_rate': 0.06053296103891895, 'subsample': 0.6575096288722778, 'colsample_bytree': 0.9986953864782131, 'gamma': 1.6170283683415891, 'min_child_weight': 4, 'reg_alpha': 4.857319720945065e-05, 'reg_lambda': 0.0005131337259674371}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:37,223] Trial 38 finished with value: 15.527386873496875 and parameters: {'n_estimators': 157, 'max_depth': 14, 'learning_rate': 0.39457069692307095, 'subsample': 0.754603290159203, 'colsample_bytree': 0.8906857751819206, 'gamma': 1.9813035779509978, 'min_child_weight': 3, 'reg_alpha': 0.00035094592962700127, 'reg_lambda': 2.367202148582351e-05}. Best is trial 26 with value: 12.495726689936896.
# [I 2024-11-29 13:15:38,919] Trial 39 finished with value: 26.916186974664818 and parameters: {'n_estimators': 140, 'max_depth': 3, 'learning_rate': 0.27530597839151694, 'subsample': 0.894585864069314, 'colsample_bytree': 0.7287278501805544, 'gamma': 0.11250523142100732, 'min_child_weight': 2, 'reg_alpha': 0.024393533459074714, 'reg_lambda': 0.013064474768527247}. Best is trial 26 with value: 12.495726689936896.
# Modelo salvo como: xgb_model_2023-11-29_to_2024-11-28.pkl
